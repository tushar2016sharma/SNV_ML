# %%
import os
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.utils import class_weight, shuffle, resample
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, f1_score, cohen_kappa_score, precision_score, recall_score, precision_recall_curve, auc, roc_auc_score, make_scorer

import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import Recall
from tensorflow.keras.metrics import Metric
#from focal_loss import SparseCategoricalFocalLoss
from tensorflow.keras.losses import Loss
from keras.losses import BinaryFocalCrossentropy
from tensorflow.keras.layers import Input, Dense, Concatenate, Dropout, Flatten, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard

from imblearn.over_sampling import SMOTE
from sklearn.decomposition import PCA, TruncatedSVD

# %%
# LOADING DATA
def load_sample_data(var_path, ref_path, target_path):
    var_df = pd.read_csv(var_path, index_col = 0)   # variant reads
    ref_df = pd.read_csv(ref_path, index_col = 0)   # reference reads
    target_df = pd.read_csv(target_path)            # target labels

    # handling missing values
    var_df.dropna(axis = 1, how = 'any', inplace = True)
    ref_df.dropna(axis = 1, how = 'any', inplace = True)

    assert var_df.index.equals(ref_df.index) and var_df.columns.equals(ref_df.columns)

    # filtering out the SNVs where MutationType is -1 (neither class)
    snvs_to_remove = target_df[target_df['MutationType'] == -1]['SNV']
    var_df_filtered = var_df[~var_df.index.isin(snvs_to_remove)]
    ref_df_filtered = ref_df[~ref_df.index.isin(snvs_to_remove)]
    target_df_filtered = target_df[~target_df['SNV'].isin(snvs_to_remove)]

    print('var_filt shape:', var_df_filtered.shape, 'ref_filt shape:', ref_df_filtered.shape, 'target_filt shape:', target_df_filtered.shape)

    return var_df_filtered, ref_df_filtered, target_df_filtered['MutationType'].values

    #return var_df, ref_df, target_df['gsr'].values    # 'MutationType' if data is of nanopore, else 'gsr'

# %%
# DATA PREPROCESSING (WITHOUT BASE FEATURES)

def preprocess_data(var_df, ref_df, y_arr, explained_variance_threshold = 0.70, apply_svd = True, sample_id = None, output_dir = None):
    X_var = var_df.values[:, 1:]  # ignoring the SNV index
    X_ref = ref_df.values[:, 1:]
    y_arr = y_arr.astype(int)

    # converting classes to binary
    y_arr[y_arr == 1] = 0  # DNA class
    y_arr[y_arr == 2] = 1  # RNA class

    # combining variant and reference read data
    combined_data = np.hstack((X_var, X_ref, y_arr.reshape(-1, 1)))
    combined_data_shuffled = shuffle(combined_data)

    # re-splitting data into respective sets
    X_var_shuffled = combined_data_shuffled[:, :X_var.shape[1]]
    X_ref_shuffled = combined_data_shuffled[:, X_var.shape[1] : X_var.shape[1] + X_ref.shape[1]]
    y_shuffled = combined_data_shuffled[:, -1].astype(int)

    # 60-20-20 train-val-test split
    X_var_temp, X_var_test, X_ref_temp, X_ref_test, y_temp, y_test = train_test_split(X_var_shuffled, X_ref_shuffled,
                                                                                      y_shuffled, test_size = 0.2, random_state = 1, stratify = y_shuffled)

    X_var_train, X_var_val, X_ref_train, X_ref_val, y_train, y_val = train_test_split(X_var_temp, X_ref_temp,
                                                                                      y_temp, test_size = 0.25, random_state = 1, stratify = y_temp)

    # scaling the data
    scaler_var = StandardScaler()
    X_var_train_scaled = scaler_var.fit_transform(X_var_train)
    X_var_val_scaled = scaler_var.transform(X_var_val)
    X_var_test_scaled = scaler_var.transform(X_var_test)

    scaler_ref = StandardScaler()
    X_ref_train_scaled = scaler_ref.fit_transform(X_ref_train)
    X_ref_val_scaled = scaler_ref.transform(X_ref_val)
    X_ref_test_scaled = scaler_ref.transform(X_ref_test)

    # combining scaled data
    X_train_combined = np.hstack((X_var_train_scaled, X_ref_train_scaled))
    X_val_combined = np.hstack((X_var_val_scaled, X_ref_val_scaled))
    X_test_combined = np.hstack((X_var_test_scaled, X_ref_test_scaled))

    if apply_svd:
        # dimensionality reduction using TruncatedSVD
        initial_svd = TruncatedSVD(n_components = min(X_train_combined.shape[1], 1000))  # generally, ~ 95% variance is explained with < 1000 components
        X_train_svd = initial_svd.fit_transform(X_train_combined)

        cumulative_variance = np.cumsum(initial_svd.explained_variance_ratio_)
        n_comp = np.argmax(cumulative_variance >= explained_variance_threshold) + 1    # no. of components explaining the threshold variance

        svd_optimal = TruncatedSVD(n_components = n_comp)
        X_train_svd = svd_optimal.fit_transform(X_train_combined)
        X_val_svd = svd_optimal.transform(X_val_combined)
        X_test_svd = svd_optimal.transform(X_test_combined)

        if output_dir and sample_id:
            plt.figure(figsize = (7, 5))
            plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker = 'o', linestyle = '--')
            plt.xlabel('Number of components')
            plt.ylabel('Cumulative explained variance')
            plt.title(f'TruncatedSVD explained variance - {sample_id}')
            plt.axvline(n_comp, color = 'r', linestyle = '--',
                        label = f'{round(explained_variance_threshold * 100)}% variance ({n_comp} components)')
            plt.legend()
            plt_path = os.path.join(output_dir, f'{sample_id}_svd_explained_variance.png')
            plt.savefig(plt_path, dpi = 500)
            plt.close()

        X_train_combined_final = X_train_svd
        X_val_combined_final = X_val_svd
        X_test_combined_final = X_test_svd
    else:
        # If not applying SVD, just pass the scaled combined data forward
        X_train_combined_final = X_train_combined
        X_val_combined_final = X_val_combined
        X_test_combined_final = X_test_combined
        n_comp = None

    return X_train_combined_final, X_val_combined_final, X_test_combined_final, y_train, y_val, y_test, n_comp

# %%
# class weights function  (either use this or SMOTE oversampling)
def compute_class_weights(y_train):
    class_weights = class_weight.compute_class_weight(class_weight = 'balanced',
                                                      classes = np.unique(y_train),
                                                      y = y_train)
    return dict(enumerate(class_weights))

# %%
def focal_loss(alpha=0.25, gamma=2.0):
    def loss(y_true, y_pred):
        # Clip predictions to avoid log(0) error
        y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())

        # Calculate focal loss
        pt = y_true * y_pred + (1 - y_true) * (1 - y_pred)  # Probabilities of true class
        fl = -alpha * (1 - pt) ** gamma * K.log(pt)
        return K.mean(fl, axis=0)
    return loss

# %%
# Fixed Neural Network Architecture (back and forth between shallow and deeper network)

# def build_fixed_model(input_shape):
#     model = Sequential()
#     model.add(layers.Input(shape = (input_shape,)))

#     model.add(layers.Dense(800, activation = 'relu'))
#     model.add(layers.BatchNormalization())
#     model.add(layers.Dropout(0.3))

#     model.add(layers.Dense(400, activation = 'relu'))
#     model.add(layers.BatchNormalization())
#     model.add(layers.Dropout(0.3))

#     model.add(layers.Dense(200, activation = 'relu'))
#     model.add(layers.BatchNormalization())
#     model.add(layers.Dropout(0.3))

#     model.add(layers.Dense(1, activation = 'sigmoid'))

#     model.compile(
#         optimizer = Adam(learning_rate = 0.001),
#         loss = 'binary_crossentropy',
#         metrics = [
#             tf.keras.metrics.BinaryAccuracy(name = 'accuracy'),
#             tf.keras.metrics.Precision(name = 'precision'),
#             tf.keras.metrics.Recall(name = 'recall'),
#             tf.keras.metrics.AUC(name = 'auc'),
#         ]
#     )

#     return model


def build_fixed_model(input_shape):
    model = Sequential()
    model.add(layers.Input(shape = (input_shape,)))

    model.add(layers.Dense(3200, activation = 'relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.3))

    model.add(layers.Dense(1600, activation = 'relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.3))

    model.add(layers.Dense(800, activation = 'relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.3))

    model.add(layers.Dense(400, activation = 'relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.3))

    model.add(layers.Dense(200, activation = 'relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.3))

    model.add(layers.Dense(100, activation = 'relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.3))

    model.add(layers.Dense(1, activation = 'sigmoid'))


    model.compile(
        optimizer = Adam(learning_rate = 0.001),
        loss = focal_loss(alpha = 0.25, gamma = 2.0),  # using Focal Loss
        metrics=[
            tf.keras.metrics.BinaryAccuracy(name = 'accuracy'),
            tf.keras.metrics.Precision(name = 'precision'),
            tf.keras.metrics.Recall(name = 'recall'),
            tf.keras.metrics.AUC(name = 'auc'),
        ]
    )

    return model

# %%
def evaluate_model(model, X_test, y_test, sample_id, output_dir):
    y_pred_probs = model.predict(X_test)
    y_pred = (y_pred_probs > 0.5).astype(int)

    # evaluation metrics
    conf_matrix = confusion_matrix(y_test, y_pred)
    f1_macro = f1_score(y_test, y_pred, average = 'macro')
    precision_macro = precision_score(y_test, y_pred, average = 'macro')
    recall_macro = recall_score(y_test, y_pred, average = 'macro')
    roc_auc = roc_auc_score(y_test, y_pred_probs)
    kappa = cohen_kappa_score(y_test, y_pred)

    plt.figure(figsize = (7, 5))
    sns.heatmap(conf_matrix, annot = True, fmt = 'd', cmap = 'Blues',
                xticklabels = ['DNA', 'RNA'], yticklabels = ['DNA', 'RNA'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix for {sample_id}')
    image_path = os.path.join(output_dir, f'{sample_id}_conf_mat.png')
    plt.savefig(image_path, dpi = 300)
    plt.close()

    return f1_macro, kappa, precision_macro, recall_macro, roc_auc, conf_matrix

# %%
# Main Execution
# base_dir = "C:\\Users\\tusha\\Downloads\\ML_dna_rna"
output_dir_base = "nn_binary_results_focal/nn_expanded_architecture_focal"

# if not os.path.exists(output_dir_base):
#     os.makedirs(output_dir_base)

sample_ids = ['nanopore_SRR21492154', 'nanopore_SRR21492155', 'nanopore_SRR21492156',
             'nanopore_SRR21492157', 'nanopore_SRR21492158', 'nanopore_SRR21492159']

explained_variance_thresholds = [0.95]

all_results = []

for sample_id in sample_ids:
    #var_path = os.path.join(base_dir, f"{sample_id}_varreads.csv")
    #ref_path = os.path.join(base_dir, f"{sample_id}_refreads.csv")
    var_path = f"{sample_id}_varreads.csv"
    ref_path = f"{sample_id}_refreads.csv"
    target_path = f"{sample_id}_targets.csv"
    print(f"\nProcessing sample: {sample_id}")

    # load data
    var_df, ref_df, y_arr = load_sample_data(var_path, ref_path, target_path)

    for explained_variance_threshold in explained_variance_thresholds + [None]:
        if explained_variance_threshold is None:
            output_dir = os.path.join(output_dir_base, "no_svd")
        else:
            output_dir = os.path.join(output_dir_base, f"svd_{int(explained_variance_threshold * 100)}_variance")

        if not os.path.exists(output_dir):
            os.makedirs(output_dir)

        #print(f"\nRunning pipeline with TruncatedSVD at {int(explained_variance_threshold * 100) if explained_variance_threshold else 'No'}% explained variance")

        # preprocessing call
        # X_train_combined_final, X_val_combined_final, X_test_combined_final, y_train, y_val, y_test, n_comp = preprocess_data(
        #     var_df, ref_df, y_arr, explained_variance_threshold=explained_variance_threshold, apply_svd=bool(explained_variance_threshold),
        #     sample_id=sample_id, output_dir=output_dir)
        X_train_combined_final, X_val_combined_final, X_test_combined_final, y_train, y_val, y_test, _ = preprocess_data(var_df, ref_df, y_arr, explained_variance_threshold = None,
                                                                                                                         apply_svd = False, sample_id = sample_id, output_dir = output_dir)
        y_train = y_train.astype(int)
        y_val = y_val.astype(int)
        y_test = y_test.astype(int)


        # model training and evaluation calls
        model = build_fixed_model(X_train_combined_final.shape[1])

        callbacks = [EarlyStopping(monitor = 'val_loss', patience = 10, restore_best_weights = True),
                     TensorBoard(log_dir = os.path.join(output_dir, f"logs/{sample_id}"))]

        model.fit(X_train_combined_final, y_train,
                  validation_data = (X_val_combined_final, y_val),
                  epochs = 50, callbacks = callbacks, verbose = 2)

        f1_macro, kappa, precision_macro, recall_macro, roc_auc, conf_matrix = evaluate_model(model, X_test_combined_final, y_test, sample_id, output_dir)

        all_results.append({
            'sample_id': sample_id,
            'explained_variance_threshold': explained_variance_threshold if explained_variance_threshold else 'No SVD',
            #'n_comp': n_comp,
            'f1_macro': f1_macro,
            'kappa': kappa,
            'precision_macro': precision_macro,
            'recall_macro': recall_macro,
            'roc_auc': roc_auc,
        })

results_df = pd.DataFrame(all_results)
results_csv_path = os.path.join(output_dir_base, 'nn_expanded_architecture_results.csv')  # back and forth between shallow and deeper network
results_df.to_csv(results_csv_path, index = False)
print("All results saved to CSV.")
# Out:
# Processing sample: nanopore_SRR21492154
# var_filt shape: (5117, 1192) ref_filt shape: (5117, 1192) target_filt shape: (5117, 2)
# Epoch 1/50
# 96/96 - 29s - 304ms/step - accuracy: 0.7058 - auc: 0.6814 - loss: 0.0757 - precision: 0.3386 - recall: 0.5429 - val_accuracy: 0.2559 - val_auc: 0.3063 - val_loss: 0.4349 - val_precision: 0.1723 - val_recall: 0.7437
# Epoch 2/50
# 96/96 - 38s - 391ms/step - accuracy: 0.7937 - auc: 0.7293 - loss: 0.0471 - precision: 0.4675 - recall: 0.4588 - val_accuracy: 0.8281 - val_auc: 0.7319 - val_loss: 0.0343 - val_precision: 0.5762 - val_recall: 0.4372
# Epoch 3/50
# 96/96 - 20s - 212ms/step - accuracy: 0.8286 - auc: 0.7946 - loss: 0.0385 - precision: 0.5628 - recall: 0.5193 - val_accuracy: 0.8574 - val_auc: 0.8848 - val_loss: 0.0223 - val_precision: 0.7227 - val_recall: 0.4322
# Epoch 4/50
# 96/96 - 21s - 218ms/step - accuracy: 0.8276 - auc: 0.8211 - loss: 0.0340 - precision: 0.5623 - recall: 0.5008 - val_accuracy: 0.8838 - val_auc: 0.9039 - val_loss: 0.0245 - val_precision: 0.6980 - val_recall: 0.7085
# Epoch 5/50
# 96/96 - 40s - 412ms/step - accuracy: 0.8423 - auc: 0.8598 - loss: 0.0282 - precision: 0.5989 - recall: 0.5647 - val_accuracy: 0.8779 - val_auc: 0.8962 - val_loss: 0.0238 - val_precision: 0.7056 - val_recall: 0.6382
# Epoch 6/50
# 96/96 - 22s - 231ms/step - accuracy: 0.8638 - auc: 0.8850 - loss: 0.0253 - precision: 0.6561 - recall: 0.6252 - val_accuracy: 0.8516 - val_auc: 0.8522 - val_loss: 0.0269 - val_precision: 0.6621 - val_recall: 0.4824
# Epoch 7/50
# 96/96 - 38s - 400ms/step - accuracy: 0.8667 - auc: 0.8975 - loss: 0.0229 - precision: 0.6716 - recall: 0.6118 - val_accuracy: 0.7705 - val_auc: 0.7923 - val_loss: 0.0281 - val_precision: 0.3861 - val_recall: 0.3065
# Epoch 8/50
# 96/96 - 21s - 223ms/step - accuracy: 0.8710 - auc: 0.9014 - loss: 0.0236 - precision: 0.6806 - recall: 0.6303 - val_accuracy: 0.8545 - val_auc: 0.9024 - val_loss: 0.0205 - val_precision: 0.7451 - val_recall: 0.3819
# Epoch 9/50
# 96/96 - 20s - 207ms/step - accuracy: 0.8791 - auc: 0.9094 - loss: 0.0223 - precision: 0.7022 - recall: 0.6538 - val_accuracy: 0.8535 - val_auc: 0.8915 - val_loss: 0.0209 - val_precision: 0.7094 - val_recall: 0.4171
# Epoch 10/50
# 96/96 - 20s - 205ms/step - accuracy: 0.8935 - auc: 0.9347 - loss: 0.0180 - precision: 0.7428 - recall: 0.6891 - val_accuracy: 0.8506 - val_auc: 0.8724 - val_loss: 0.0224 - val_precision: 0.6420 - val_recall: 0.5226
# Epoch 11/50
# 96/96 - 21s - 217ms/step - accuracy: 0.8879 - auc: 0.9317 - loss: 0.0187 - precision: 0.7245 - recall: 0.6807 - val_accuracy: 0.8564 - val_auc: 0.8942 - val_loss: 0.0221 - val_precision: 0.7131 - val_recall: 0.4372
# Epoch 12/50
# 96/96 - 27s - 280ms/step - accuracy: 0.8961 - auc: 0.9378 - loss: 0.0179 - precision: 0.7491 - recall: 0.6975 - val_accuracy: 0.8711 - val_auc: 0.8854 - val_loss: 0.0220 - val_precision: 0.6438 - val_recall: 0.7538
# Epoch 13/50
# 96/96 - 34s - 358ms/step - accuracy: 0.8957 - auc: 0.9407 - loss: 0.0171 - precision: 0.7417 - recall: 0.7092 - val_accuracy: 0.8857 - val_auc: 0.8971 - val_loss: 0.0216 - val_precision: 0.7595 - val_recall: 0.6030
# Epoch 14/50
# 96/96 - 20s - 206ms/step - accuracy: 0.9032 - auc: 0.9507 - loss: 0.0157 - precision: 0.7633 - recall: 0.7261 - val_accuracy: 0.8154 - val_auc: 0.8404 - val_loss: 0.0257 - val_precision: 0.5281 - val_recall: 0.4724
# Epoch 15/50
# 96/96 - 22s - 232ms/step - accuracy: 0.9120 - auc: 0.9525 - loss: 0.0149 - precision: 0.7866 - recall: 0.7496 - val_accuracy: 0.8740 - val_auc: 0.8805 - val_loss: 0.0208 - val_precision: 0.7011 - val_recall: 0.6131
# Epoch 16/50
# 96/96 - 19s - 198ms/step - accuracy: 0.9146 - auc: 0.9617 - loss: 0.0133 - precision: 0.7827 - recall: 0.7748 - val_accuracy: 0.8662 - val_auc: 0.8773 - val_loss: 0.0220 - val_precision: 0.6535 - val_recall: 0.6633
# Epoch 17/50
# 96/96 - 21s - 220ms/step - accuracy: 0.9146 - auc: 0.9664 - loss: 0.0125 - precision: 0.7856 - recall: 0.7697 - val_accuracy: 0.8682 - val_auc: 0.8770 - val_loss: 0.0236 - val_precision: 0.7105 - val_recall: 0.5427
# Epoch 18/50
# 96/96 - 19s - 195ms/step - accuracy: 0.9156 - auc: 0.9589 - loss: 0.0138 - precision: 0.7947 - recall: 0.7613 - val_accuracy: 0.8604 - val_auc: 0.8764 - val_loss: 0.0216 - val_precision: 0.6750 - val_recall: 0.5427
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# Epoch 1/50
# 96/96 - 25s - 259ms/step - accuracy: 0.6882 - auc: 0.6780 - loss: 0.0746 - precision: 0.3222 - recall: 0.5513 - val_accuracy: 0.8486 - val_auc: 0.8206 - val_loss: 0.0550 - val_precision: 0.6642 - val_recall: 0.4472
# Epoch 2/50
# 96/96 - 19s - 198ms/step - accuracy: 0.7915 - auc: 0.7474 - loss: 0.0432 - precision: 0.4646 - recall: 0.4958 - val_accuracy: 0.8398 - val_auc: 0.7841 - val_loss: 0.0304 - val_precision: 0.6966 - val_recall: 0.3116
# Epoch 3/50
# 96/96 - 24s - 245ms/step - accuracy: 0.8038 - auc: 0.7913 - loss: 0.0371 - precision: 0.4941 - recall: 0.4958 - val_accuracy: 0.8438 - val_auc: 0.7815 - val_loss: 0.0272 - val_precision: 0.7671 - val_recall: 0.2814
# Epoch 4/50
# 96/96 - 38s - 398ms/step - accuracy: 0.8247 - auc: 0.8343 - loss: 0.0301 - precision: 0.5515 - recall: 0.5126 - val_accuracy: 0.8535 - val_auc: 0.8756 - val_loss: 0.0221 - val_precision: 0.7475 - val_recall: 0.3719
# Epoch 5/50
# 96/96 - 22s - 228ms/step - accuracy: 0.8472 - auc: 0.8579 - loss: 0.0273 - precision: 0.6109 - recall: 0.5832 - val_accuracy: 0.8750 - val_auc: 0.8890 - val_loss: 0.0204 - val_precision: 0.6898 - val_recall: 0.6482
# Epoch 6/50
# 96/96 - 39s - 407ms/step - accuracy: 0.8586 - auc: 0.8883 - loss: 0.0234 - precision: 0.6344 - recall: 0.6387 - val_accuracy: 0.8447 - val_auc: 0.8935 - val_loss: 0.0212 - val_precision: 0.8125 - val_recall: 0.2613
# Epoch 7/50
# 96/96 - 19s - 198ms/step - accuracy: 0.8684 - auc: 0.8989 - loss: 0.0220 - precision: 0.6616 - recall: 0.6571 - val_accuracy: 0.8867 - val_auc: 0.9007 - val_loss: 0.0202 - val_precision: 0.7515 - val_recall: 0.6231
# Epoch 8/50
# 96/96 - 23s - 242ms/step - accuracy: 0.8726 - auc: 0.9178 - loss: 0.0192 - precision: 0.6789 - recall: 0.6504 - val_accuracy: 0.8750 - val_auc: 0.8931 - val_loss: 0.0208 - val_precision: 0.6498 - val_recall: 0.7739
# Epoch 9/50
# 96/96 - 22s - 228ms/step - accuracy: 0.8778 - auc: 0.9201 - loss: 0.0193 - precision: 0.6903 - recall: 0.6706 - val_accuracy: 0.8535 - val_auc: 0.8832 - val_loss: 0.0238 - val_precision: 0.8657 - val_recall: 0.2915
# Epoch 10/50
# 96/96 - 40s - 418ms/step - accuracy: 0.8860 - auc: 0.9261 - loss: 0.0183 - precision: 0.7130 - recall: 0.6891 - val_accuracy: 0.8506 - val_auc: 0.8972 - val_loss: 0.0216 - val_precision: 0.7875 - val_recall: 0.3166
# Epoch 11/50
# 96/96 - 39s - 407ms/step - accuracy: 0.8921 - auc: 0.9330 - loss: 0.0173 - precision: 0.7332 - recall: 0.6975 - val_accuracy: 0.8857 - val_auc: 0.8933 - val_loss: 0.0197 - val_precision: 0.7531 - val_recall: 0.6131
# Epoch 12/50
# 96/96 - 22s - 224ms/step - accuracy: 0.9000 - auc: 0.9398 - loss: 0.0165 - precision: 0.7474 - recall: 0.7311 - val_accuracy: 0.8701 - val_auc: 0.8732 - val_loss: 0.0256 - val_precision: 0.6941 - val_recall: 0.5930
# Epoch 13/50
# 96/96 - 20s - 204ms/step - accuracy: 0.9052 - auc: 0.9543 - loss: 0.0146 - precision: 0.7550 - recall: 0.7563 - val_accuracy: 0.8643 - val_auc: 0.8863 - val_loss: 0.0214 - val_precision: 0.7083 - val_recall: 0.5126
# Epoch 14/50
# 96/96 - 20s - 211ms/step - accuracy: 0.9137 - auc: 0.9611 - loss: 0.0135 - precision: 0.7750 - recall: 0.7815 - val_accuracy: 0.8760 - val_auc: 0.8759 - val_loss: 0.0241 - val_precision: 0.7118 - val_recall: 0.6080
# Epoch 15/50
# 96/96 - 20s - 203ms/step - accuracy: 0.9052 - auc: 0.9560 - loss: 0.0140 - precision: 0.7550 - recall: 0.7563 - val_accuracy: 0.8740 - val_auc: 0.8891 - val_loss: 0.0211 - val_precision: 0.7035 - val_recall: 0.6080
# Epoch 16/50
# 96/96 - 20s - 212ms/step - accuracy: 0.9143 - auc: 0.9670 - loss: 0.0122 - precision: 0.7814 - recall: 0.7748 - val_accuracy: 0.8535 - val_auc: 0.8699 - val_loss: 0.0226 - val_precision: 0.6815 - val_recall: 0.4623
# Epoch 17/50
# 96/96 - 21s - 224ms/step - accuracy: 0.9221 - auc: 0.9665 - loss: 0.0122 - precision: 0.7987 - recall: 0.8000 - val_accuracy: 0.8760 - val_auc: 0.8690 - val_loss: 0.0231 - val_precision: 0.6748 - val_recall: 0.6985
# Epoch 18/50
# 96/96 - 19s - 196ms/step - accuracy: 0.9286 - auc: 0.9694 - loss: 0.0116 - precision: 0.8154 - recall: 0.8168 - val_accuracy: 0.8516 - val_auc: 0.8775 - val_loss: 0.0249 - val_precision: 0.7080 - val_recall: 0.4020
# Epoch 19/50
# 96/96 - 21s - 216ms/step - accuracy: 0.9143 - auc: 0.9671 - loss: 0.0124 - precision: 0.7852 - recall: 0.7681 - val_accuracy: 0.8252 - val_auc: 0.8385 - val_loss: 0.0268 - val_precision: 0.5568 - val_recall: 0.4925
# Epoch 20/50
# 96/96 - 20s - 204ms/step - accuracy: 0.9257 - auc: 0.9682 - loss: 0.0121 - precision: 0.7936 - recall: 0.8336 - val_accuracy: 0.8633 - val_auc: 0.8776 - val_loss: 0.0271 - val_precision: 0.7153 - val_recall: 0.4925
# Epoch 21/50
# 96/96 - 22s - 230ms/step - accuracy: 0.9339 - auc: 0.9741 - loss: 0.0107 - precision: 0.8300 - recall: 0.8286 - val_accuracy: 0.8594 - val_auc: 0.8677 - val_loss: 0.0262 - val_precision: 0.7007 - val_recall: 0.4824
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
#
# Processing sample: nanopore_SRR21492155
# var_filt shape: (428, 9366) ref_filt shape: (428, 9366) target_filt shape: (428, 2)
# Epoch 1/50
# 8/8 - 18s - 2s/step - accuracy: 0.5391 - auc: 0.5826 - loss: 0.1084 - precision: 0.2566 - recall: 0.4603 - val_accuracy: 0.8372 - val_auc: 0.7495 - val_loss: 0.2098 - val_precision: 0.7059 - val_recall: 0.5714
# Epoch 2/50
# 8/8 - 17s - 2s/step - accuracy: 0.6797 - auc: 0.7779 - loss: 0.0724 - precision: 0.4159 - recall: 0.7460 - val_accuracy: 0.3953 - val_auc: 0.9176 - val_loss: 0.4728 - val_precision: 0.2817 - val_recall: 0.9524
# Epoch 3/50
# 8/8 - 11s - 1s/step - accuracy: 0.7500 - auc: 0.8702 - loss: 0.0610 - precision: 0.4956 - recall: 0.8889 - val_accuracy: 0.3605 - val_auc: 0.5982 - val_loss: 1.4503 - val_precision: 0.2703 - val_recall: 0.9524
# Epoch 4/50
# 8/8 - 20s - 3s/step - accuracy: 0.7070 - auc: 0.7761 - loss: 0.0752 - precision: 0.4423 - recall: 0.7302 - val_accuracy: 0.3721 - val_auc: 0.6234 - val_loss: 1.2229 - val_precision: 0.2740 - val_recall: 0.9524
# Epoch 5/50
# 8/8 - 22s - 3s/step - accuracy: 0.7148 - auc: 0.7943 - loss: 0.0552 - precision: 0.4510 - recall: 0.7302 - val_accuracy: 0.3953 - val_auc: 0.9055 - val_loss: 0.4970 - val_precision: 0.2817 - val_recall: 0.9524
# Epoch 6/50
# 8/8 - 19s - 2s/step - accuracy: 0.7695 - auc: 0.8055 - loss: 0.0557 - precision: 0.5238 - recall: 0.6984 - val_accuracy: 0.4186 - val_auc: 0.8663 - val_loss: 0.4546 - val_precision: 0.2899 - val_recall: 0.9524
# Epoch 7/50
# 8/8 - 12s - 1s/step - accuracy: 0.7852 - auc: 0.8514 - loss: 0.0448 - precision: 0.5500 - recall: 0.6984 - val_accuracy: 0.4419 - val_auc: 0.9289 - val_loss: 0.2879 - val_precision: 0.2985 - val_recall: 0.9524
# Epoch 8/50
# 8/8 - 20s - 2s/step - accuracy: 0.8125 - auc: 0.8468 - loss: 0.0457 - precision: 0.6027 - recall: 0.6984 - val_accuracy: 0.5000 - val_auc: 0.9249 - val_loss: 0.1710 - val_precision: 0.3226 - val_recall: 0.9524
# Epoch 9/50
# 8/8 - 21s - 3s/step - accuracy: 0.8438 - auc: 0.8648 - loss: 0.0484 - precision: 0.6620 - recall: 0.7460 - val_accuracy: 0.8488 - val_auc: 0.9333 - val_loss: 0.0727 - val_precision: 0.7500 - val_recall: 0.5714
# Epoch 10/50
# 8/8 - 21s - 3s/step - accuracy: 0.8438 - auc: 0.9289 - loss: 0.0276 - precision: 0.6353 - recall: 0.8571 - val_accuracy: 0.4651 - val_auc: 0.7861 - val_loss: 0.1184 - val_precision: 0.2881 - val_recall: 0.8095
# Epoch 11/50
# 8/8 - 19s - 2s/step - accuracy: 0.8281 - auc: 0.8693 - loss: 0.0374 - precision: 0.6234 - recall: 0.7619 - val_accuracy: 0.4302 - val_auc: 0.8447 - val_loss: 0.2443 - val_precision: 0.2941 - val_recall: 0.9524
# Epoch 12/50
# 8/8 - 12s - 2s/step - accuracy: 0.8047 - auc: 0.8516 - loss: 0.0453 - precision: 0.5890 - recall: 0.6825 - val_accuracy: 0.8372 - val_auc: 0.9344 - val_loss: 0.0627 - val_precision: 0.6842 - val_recall: 0.6190
# Epoch 13/50
# 8/8 - 19s - 2s/step - accuracy: 0.8281 - auc: 0.9056 - loss: 0.0295 - precision: 0.6173 - recall: 0.7937 - val_accuracy: 0.8837 - val_auc: 0.9414 - val_loss: 0.0458 - val_precision: 0.7200 - val_recall: 0.8571
# Epoch 14/50
# 8/8 - 12s - 1s/step - accuracy: 0.8594 - auc: 0.9128 - loss: 0.0288 - precision: 0.6800 - recall: 0.8095 - val_accuracy: 0.8953 - val_auc: 0.9326 - val_loss: 0.0463 - val_precision: 0.7143 - val_recall: 0.9524
# Epoch 15/50
# 8/8 - 19s - 2s/step - accuracy: 0.8438 - auc: 0.9055 - loss: 0.0262 - precision: 0.6716 - recall: 0.7143 - val_accuracy: 0.8953 - val_auc: 0.9399 - val_loss: 0.0406 - val_precision: 0.7308 - val_recall: 0.9048
# Epoch 16/50
# 8/8 - 12s - 1s/step - accuracy: 0.8828 - auc: 0.9363 - loss: 0.0293 - precision: 0.7391 - recall: 0.8095 - val_accuracy: 0.8256 - val_auc: 0.9106 - val_loss: 0.0801 - val_precision: 0.6667 - val_recall: 0.5714
# Epoch 17/50
# 8/8 - 19s - 2s/step - accuracy: 0.8516 - auc: 0.9213 - loss: 0.0310 - precision: 0.6761 - recall: 0.7619 - val_accuracy: 0.8721 - val_auc: 0.9249 - val_loss: 0.0369 - val_precision: 0.7083 - val_recall: 0.8095
# Epoch 18/50
# 8/8 - 12s - 1s/step - accuracy: 0.8672 - auc: 0.9291 - loss: 0.0257 - precision: 0.7101 - recall: 0.7778 - val_accuracy: 0.8256 - val_auc: 0.9223 - val_loss: 0.0371 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 19/50
# 8/8 - 19s - 2s/step - accuracy: 0.8438 - auc: 0.8977 - loss: 0.0308 - precision: 0.6533 - recall: 0.7778 - val_accuracy: 0.8140 - val_auc: 0.9125 - val_loss: 0.0375 - val_precision: 0.6471 - val_recall: 0.5238
# Epoch 20/50
# 8/8 - 12s - 1s/step - accuracy: 0.8828 - auc: 0.9327 - loss: 0.0213 - precision: 0.7538 - recall: 0.7778 - val_accuracy: 0.8256 - val_auc: 0.9190 - val_loss: 0.0350 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 21/50
# 8/8 - 18s - 2s/step - accuracy: 0.8945 - auc: 0.9477 - loss: 0.0198 - precision: 0.7368 - recall: 0.8889 - val_accuracy: 0.8953 - val_auc: 0.9282 - val_loss: 0.0375 - val_precision: 0.7143 - val_recall: 0.9524
# Epoch 22/50
# 8/8 - 12s - 1s/step - accuracy: 0.9141 - auc: 0.9670 - loss: 0.0167 - precision: 0.7971 - recall: 0.8730 - val_accuracy: 0.8721 - val_auc: 0.9238 - val_loss: 0.0371 - val_precision: 0.7083 - val_recall: 0.8095
# Epoch 23/50
# 8/8 - 19s - 2s/step - accuracy: 0.8906 - auc: 0.9407 - loss: 0.0260 - precision: 0.7273 - recall: 0.8889 - val_accuracy: 0.8953 - val_auc: 0.9220 - val_loss: 0.0332 - val_precision: 0.7500 - val_recall: 0.8571
# Epoch 24/50
# 8/8 - 12s - 2s/step - accuracy: 0.8867 - auc: 0.9456 - loss: 0.0265 - precision: 0.7361 - recall: 0.8413 - val_accuracy: 0.8605 - val_auc: 0.9245 - val_loss: 0.0352 - val_precision: 0.6957 - val_recall: 0.7619
# Epoch 25/50
# 8/8 - 19s - 2s/step - accuracy: 0.9102 - auc: 0.9574 - loss: 0.0213 - precision: 0.8030 - recall: 0.8413 - val_accuracy: 0.8605 - val_auc: 0.9176 - val_loss: 0.0325 - val_precision: 0.7368 - val_recall: 0.6667
# Epoch 26/50
# 8/8 - 13s - 2s/step - accuracy: 0.9180 - auc: 0.9717 - loss: 0.0148 - precision: 0.8088 - recall: 0.8730 - val_accuracy: 0.8488 - val_auc: 0.9055 - val_loss: 0.0334 - val_precision: 0.7000 - val_recall: 0.6667
# Epoch 27/50
# 8/8 - 17s - 2s/step - accuracy: 0.9297 - auc: 0.9590 - loss: 0.0168 - precision: 0.8814 - recall: 0.8254 - val_accuracy: 0.8256 - val_auc: 0.9139 - val_loss: 0.0354 - val_precision: 0.6500 - val_recall: 0.6190
# Epoch 28/50
# 8/8 - 11s - 1s/step - accuracy: 0.9062 - auc: 0.9669 - loss: 0.0160 - precision: 0.8000 - recall: 0.8254 - val_accuracy: 0.8837 - val_auc: 0.9209 - val_loss: 0.0306 - val_precision: 0.7391 - val_recall: 0.8095
# Epoch 29/50
# 8/8 - 19s - 2s/step - accuracy: 0.9297 - auc: 0.9737 - loss: 0.0134 - precision: 0.8462 - recall: 0.8730 - val_accuracy: 0.8721 - val_auc: 0.9150 - val_loss: 0.0349 - val_precision: 0.7083 - val_recall: 0.8095
# Epoch 30/50
# 8/8 - 12s - 1s/step - accuracy: 0.9453 - auc: 0.9788 - loss: 0.0132 - precision: 0.8451 - recall: 0.9524 - val_accuracy: 0.8721 - val_auc: 0.9264 - val_loss: 0.0307 - val_precision: 0.7083 - val_recall: 0.8095
# Epoch 31/50
# 8/8 - 19s - 2s/step - accuracy: 0.9258 - auc: 0.9796 - loss: 0.0125 - precision: 0.8333 - recall: 0.8730 - val_accuracy: 0.8256 - val_auc: 0.9190 - val_loss: 0.0379 - val_precision: 0.6667 - val_recall: 0.5714
# Epoch 32/50
# 8/8 - 11s - 1s/step - accuracy: 0.9492 - auc: 0.9837 - loss: 0.0104 - precision: 0.9167 - recall: 0.8730 - val_accuracy: 0.8721 - val_auc: 0.9286 - val_loss: 0.0335 - val_precision: 0.7273 - val_recall: 0.7619
# Epoch 33/50
# 8/8 - 18s - 2s/step - accuracy: 0.9141 - auc: 0.9688 - loss: 0.0145 - precision: 0.8060 - recall: 0.8571 - val_accuracy: 0.8721 - val_auc: 0.9330 - val_loss: 0.0358 - val_precision: 0.7273 - val_recall: 0.7619
# Epoch 34/50
# 8/8 - 11s - 1s/step - accuracy: 0.9336 - auc: 0.9795 - loss: 0.0116 - precision: 0.8710 - recall: 0.8571 - val_accuracy: 0.8372 - val_auc: 0.9249 - val_loss: 0.0429 - val_precision: 0.7059 - val_recall: 0.5714
# Epoch 35/50
# 8/8 - 19s - 2s/step - accuracy: 0.9688 - auc: 0.9933 - loss: 0.0059 - precision: 0.9231 - recall: 0.9524 - val_accuracy: 0.8837 - val_auc: 0.9407 - val_loss: 0.0366 - val_precision: 0.7619 - val_recall: 0.7619
# Epoch 36/50
# 8/8 - 12s - 2s/step - accuracy: 0.9609 - auc: 0.9916 - loss: 0.0080 - precision: 0.8841 - recall: 0.9683 - val_accuracy: 0.8837 - val_auc: 0.9407 - val_loss: 0.0349 - val_precision: 0.7619 - val_recall: 0.7619
# Epoch 37/50
# 8/8 - 18s - 2s/step - accuracy: 0.9805 - auc: 0.9966 - loss: 0.0053 - precision: 0.9531 - recall: 0.9683 - val_accuracy: 0.8837 - val_auc: 0.9381 - val_loss: 0.0373 - val_precision: 0.7619 - val_recall: 0.7619
# Epoch 38/50
# 8/8 - 12s - 2s/step - accuracy: 0.9531 - auc: 0.9895 - loss: 0.0096 - precision: 0.9048 - recall: 0.9048 - val_accuracy: 0.8721 - val_auc: 0.9366 - val_loss: 0.0425 - val_precision: 0.7500 - val_recall: 0.7143
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step
# Epoch 1/50
# 8/8 - 17s - 2s/step - accuracy: 0.5781 - auc: 0.6442 - loss: 0.1035 - precision: 0.3171 - recall: 0.6190 - val_accuracy: 0.2907 - val_auc: 0.5615 - val_loss: 1.8115 - val_precision: 0.2561 - val_recall: 1.0000
# Epoch 2/50
# 8/8 - 17s - 2s/step - accuracy: 0.6797 - auc: 0.7800 - loss: 0.0760 - precision: 0.4159 - recall: 0.7460 - val_accuracy: 0.2674 - val_auc: 0.5231 - val_loss: 2.7027 - val_precision: 0.2500 - val_recall: 1.0000
# Epoch 3/50
# 8/8 - 12s - 2s/step - accuracy: 0.7148 - auc: 0.7730 - loss: 0.0830 - precision: 0.4519 - recall: 0.7460 - val_accuracy: 0.2558 - val_auc: 0.5231 - val_loss: 2.7034 - val_precision: 0.2471 - val_recall: 1.0000
# Epoch 4/50
# 8/8 - 18s - 2s/step - accuracy: 0.6875 - auc: 0.7643 - loss: 0.0740 - precision: 0.4190 - recall: 0.6984 - val_accuracy: 0.2674 - val_auc: 0.4026 - val_loss: 2.6349 - val_precision: 0.2500 - val_recall: 1.0000
# Epoch 5/50
# 8/8 - 11s - 1s/step - accuracy: 0.7266 - auc: 0.7818 - loss: 0.0575 - precision: 0.4588 - recall: 0.6190 - val_accuracy: 0.2558 - val_auc: 0.5462 - val_loss: 2.5836 - val_precision: 0.2471 - val_recall: 1.0000
# Epoch 6/50
# 8/8 - 12s - 1s/step - accuracy: 0.7539 - auc: 0.8377 - loss: 0.0550 - precision: 0.5000 - recall: 0.7460 - val_accuracy: 0.2791 - val_auc: 0.5615 - val_loss: 2.4877 - val_precision: 0.2530 - val_recall: 1.0000
# Epoch 7/50
# 8/8 - 20s - 2s/step - accuracy: 0.7500 - auc: 0.8052 - loss: 0.0470 - precision: 0.4938 - recall: 0.6349 - val_accuracy: 0.3023 - val_auc: 0.5692 - val_loss: 2.3139 - val_precision: 0.2593 - val_recall: 1.0000
# Epoch 8/50
# 8/8 - 20s - 2s/step - accuracy: 0.7891 - auc: 0.8242 - loss: 0.0468 - precision: 0.5616 - recall: 0.6508 - val_accuracy: 0.3023 - val_auc: 0.4755 - val_loss: 1.8303 - val_precision: 0.2593 - val_recall: 1.0000
# Epoch 9/50
# 8/8 - 10s - 1s/step - accuracy: 0.8164 - auc: 0.8648 - loss: 0.0411 - precision: 0.6053 - recall: 0.7302 - val_accuracy: 0.3372 - val_auc: 0.4883 - val_loss: 1.4710 - val_precision: 0.2692 - val_recall: 1.0000
# Epoch 10/50
# 8/8 - 11s - 1s/step - accuracy: 0.7969 - auc: 0.8583 - loss: 0.0408 - precision: 0.5696 - recall: 0.7143 - val_accuracy: 0.3256 - val_auc: 0.4630 - val_loss: 1.5073 - val_precision: 0.2658 - val_recall: 1.0000
# Epoch 11/50
# 8/8 - 19s - 2s/step - accuracy: 0.8438 - auc: 0.8861 - loss: 0.0363 - precision: 0.6667 - recall: 0.7302 - val_accuracy: 0.3605 - val_auc: 0.4502 - val_loss: 1.4281 - val_precision: 0.2763 - val_recall: 1.0000
# Epoch 12/50
# 8/8 - 21s - 3s/step - accuracy: 0.8125 - auc: 0.8557 - loss: 0.0392 - precision: 0.6027 - recall: 0.6984 - val_accuracy: 0.3837 - val_auc: 0.4905 - val_loss: 1.1552 - val_precision: 0.2838 - val_recall: 1.0000
# Epoch 13/50
# 8/8 - 21s - 3s/step - accuracy: 0.8672 - auc: 0.9073 - loss: 0.0334 - precision: 0.7042 - recall: 0.7937 - val_accuracy: 0.3837 - val_auc: 0.4740 - val_loss: 0.9641 - val_precision: 0.2838 - val_recall: 1.0000
# Epoch 14/50
# 8/8 - 18s - 2s/step - accuracy: 0.8477 - auc: 0.8821 - loss: 0.0305 - precision: 0.6714 - recall: 0.7460 - val_accuracy: 0.4070 - val_auc: 0.5333 - val_loss: 0.6426 - val_precision: 0.2917 - val_recall: 1.0000
# Epoch 15/50
# 8/8 - 12s - 2s/step - accuracy: 0.8594 - auc: 0.9172 - loss: 0.0282 - precision: 0.7015 - recall: 0.7460 - val_accuracy: 0.4186 - val_auc: 0.5678 - val_loss: 0.6264 - val_precision: 0.2958 - val_recall: 1.0000
# Epoch 16/50
# 8/8 - 18s - 2s/step - accuracy: 0.8867 - auc: 0.8978 - loss: 0.0343 - precision: 0.7500 - recall: 0.8095 - val_accuracy: 0.4535 - val_auc: 0.6835 - val_loss: 0.4834 - val_precision: 0.3088 - val_recall: 1.0000
# Epoch 17/50
# 8/8 - 12s - 2s/step - accuracy: 0.8984 - auc: 0.9380 - loss: 0.0223 - precision: 0.7937 - recall: 0.7937 - val_accuracy: 0.5465 - val_auc: 0.9125 - val_loss: 0.1483 - val_precision: 0.3448 - val_recall: 0.9524
# Epoch 18/50
# 8/8 - 18s - 2s/step - accuracy: 0.9141 - auc: 0.9509 - loss: 0.0206 - precision: 0.7971 - recall: 0.8730 - val_accuracy: 0.5581 - val_auc: 0.8333 - val_loss: 0.1095 - val_precision: 0.3509 - val_recall: 0.9524
# Epoch 19/50
# 8/8 - 11s - 1s/step - accuracy: 0.9102 - auc: 0.9376 - loss: 0.0214 - precision: 0.8125 - recall: 0.8254 - val_accuracy: 0.6047 - val_auc: 0.9168 - val_loss: 0.0732 - val_precision: 0.3774 - val_recall: 0.9524
# Epoch 20/50
# 8/8 - 11s - 1s/step - accuracy: 0.8789 - auc: 0.9078 - loss: 0.0327 - precision: 0.7581 - recall: 0.7460 - val_accuracy: 0.5930 - val_auc: 0.9147 - val_loss: 0.1321 - val_precision: 0.3704 - val_recall: 0.9524
# Epoch 21/50
# 8/8 - 20s - 2s/step - accuracy: 0.9141 - auc: 0.9596 - loss: 0.0183 - precision: 0.7887 - recall: 0.8889 - val_accuracy: 0.6395 - val_auc: 0.9128 - val_loss: 0.1030 - val_precision: 0.4000 - val_recall: 0.9524
# Epoch 22/50
# 8/8 - 11s - 1s/step - accuracy: 0.9375 - auc: 0.9682 - loss: 0.0156 - precision: 0.8615 - recall: 0.8889 - val_accuracy: 0.6744 - val_auc: 0.9077 - val_loss: 0.0841 - val_precision: 0.4222 - val_recall: 0.9048
# Epoch 23/50
# 8/8 - 20s - 3s/step - accuracy: 0.9414 - auc: 0.9829 - loss: 0.0137 - precision: 0.8871 - recall: 0.8730 - val_accuracy: 0.7791 - val_auc: 0.9341 - val_loss: 0.0617 - val_precision: 0.5263 - val_recall: 0.9524
# Epoch 24/50
# 8/8 - 18s - 2s/step - accuracy: 0.9648 - auc: 0.9839 - loss: 0.0095 - precision: 0.9091 - recall: 0.9524 - val_accuracy: 0.8256 - val_auc: 0.9363 - val_loss: 0.0645 - val_precision: 0.5882 - val_recall: 0.9524
# Epoch 25/50
# 8/8 - 11s - 1s/step - accuracy: 0.9492 - auc: 0.9845 - loss: 0.0088 - precision: 0.8788 - recall: 0.9206 - val_accuracy: 0.8953 - val_auc: 0.9253 - val_loss: 0.0447 - val_precision: 0.7308 - val_recall: 0.9048
# Epoch 26/50
# 8/8 - 19s - 2s/step - accuracy: 0.9141 - auc: 0.9450 - loss: 0.0228 - precision: 0.8475 - recall: 0.7937 - val_accuracy: 0.9070 - val_auc: 0.9326 - val_loss: 0.0387 - val_precision: 0.7600 - val_recall: 0.9048
# Epoch 27/50
# 8/8 - 11s - 1s/step - accuracy: 0.9570 - auc: 0.9938 - loss: 0.0068 - precision: 0.8939 - recall: 0.9365 - val_accuracy: 0.8721 - val_auc: 0.9377 - val_loss: 0.0495 - val_precision: 0.6667 - val_recall: 0.9524
# Epoch 28/50
# 8/8 - 11s - 1s/step - accuracy: 0.9414 - auc: 0.9718 - loss: 0.0130 - precision: 0.8750 - recall: 0.8889 - val_accuracy: 0.8953 - val_auc: 0.9359 - val_loss: 0.0648 - val_precision: 0.7308 - val_recall: 0.9048
# Epoch 29/50
# 8/8 - 21s - 3s/step - accuracy: 0.9297 - auc: 0.9643 - loss: 0.0220 - precision: 0.8358 - recall: 0.8889 - val_accuracy: 0.8488 - val_auc: 0.9414 - val_loss: 0.0796 - val_precision: 0.7222 - val_recall: 0.6190
# Epoch 30/50
# 8/8 - 11s - 1s/step - accuracy: 0.9336 - auc: 0.9677 - loss: 0.0217 - precision: 0.8485 - recall: 0.8889 - val_accuracy: 0.9070 - val_auc: 0.9469 - val_loss: 0.0420 - val_precision: 0.7826 - val_recall: 0.8571
# Epoch 31/50
# 8/8 - 21s - 3s/step - accuracy: 0.9336 - auc: 0.9694 - loss: 0.0173 - precision: 0.8594 - recall: 0.8730 - val_accuracy: 0.8372 - val_auc: 0.8696 - val_loss: 0.0484 - val_precision: 0.6667 - val_recall: 0.6667
# Epoch 32/50
# 8/8 - 19s - 2s/step - accuracy: 0.9570 - auc: 0.9873 - loss: 0.0081 - precision: 0.9062 - recall: 0.9206 - val_accuracy: 0.8488 - val_auc: 0.9564 - val_loss: 0.0333 - val_precision: 0.7500 - val_recall: 0.5714
# Epoch 33/50
# 8/8 - 14s - 2s/step - accuracy: 0.9414 - auc: 0.9820 - loss: 0.0125 - precision: 0.8636 - recall: 0.9048 - val_accuracy: 0.8721 - val_auc: 0.9487 - val_loss: 0.0525 - val_precision: 0.8125 - val_recall: 0.6190
# Epoch 34/50
# 8/8 - 17s - 2s/step - accuracy: 0.9688 - auc: 0.9965 - loss: 0.0048 - precision: 0.9231 - recall: 0.9524 - val_accuracy: 0.8721 - val_auc: 0.9593 - val_loss: 0.0289 - val_precision: 0.7778 - val_recall: 0.6667
# Epoch 35/50
# 8/8 - 12s - 1s/step - accuracy: 0.9492 - auc: 0.9831 - loss: 0.0111 - precision: 0.9310 - recall: 0.8571 - val_accuracy: 0.8488 - val_auc: 0.9564 - val_loss: 0.0287 - val_precision: 0.7857 - val_recall: 0.5238
# Epoch 36/50
# 8/8 - 18s - 2s/step - accuracy: 0.9727 - auc: 0.9936 - loss: 0.0062 - precision: 0.9667 - recall: 0.9206 - val_accuracy: 0.8605 - val_auc: 0.8403 - val_loss: 0.0746 - val_precision: 0.8000 - val_recall: 0.5714
# Epoch 37/50
# 8/8 - 12s - 2s/step - accuracy: 0.9648 - auc: 0.9733 - loss: 0.0115 - precision: 0.9500 - recall: 0.9048 - val_accuracy: 0.9070 - val_auc: 0.9560 - val_loss: 0.0386 - val_precision: 0.7826 - val_recall: 0.8571
# Epoch 38/50
# 8/8 - 18s - 2s/step - accuracy: 0.9336 - auc: 0.9783 - loss: 0.0165 - precision: 0.8286 - recall: 0.9206 - val_accuracy: 0.8488 - val_auc: 0.9473 - val_loss: 0.0480 - val_precision: 0.7222 - val_recall: 0.6190
# Epoch 39/50
# 8/8 - 12s - 1s/step - accuracy: 0.9766 - auc: 0.9965 - loss: 0.0043 - precision: 0.9672 - recall: 0.9365 - val_accuracy: 0.8721 - val_auc: 0.9304 - val_loss: 0.0683 - val_precision: 0.8125 - val_recall: 0.6190
# Epoch 40/50
# 8/8 - 18s - 2s/step - accuracy: 0.9570 - auc: 0.9858 - loss: 0.0080 - precision: 0.9333 - recall: 0.8889 - val_accuracy: 0.8605 - val_auc: 0.9297 - val_loss: 0.0656 - val_precision: 0.8000 - val_recall: 0.5714
# Epoch 41/50
# 8/8 - 11s - 1s/step - accuracy: 0.9844 - auc: 0.9989 - loss: 0.0031 - precision: 0.9683 - recall: 0.9683 - val_accuracy: 0.8721 - val_auc: 0.9436 - val_loss: 0.0528 - val_precision: 0.8571 - val_recall: 0.5714
# Epoch 42/50
# 8/8 - 18s - 2s/step - accuracy: 0.9414 - auc: 0.9845 - loss: 0.0144 - precision: 0.8636 - recall: 0.9048 - val_accuracy: 0.8721 - val_auc: 0.9088 - val_loss: 0.0720 - val_precision: 0.8571 - val_recall: 0.5714
# Epoch 43/50
# 8/8 - 12s - 2s/step - accuracy: 0.9727 - auc: 0.9963 - loss: 0.0048 - precision: 0.9516 - recall: 0.9365 - val_accuracy: 0.8721 - val_auc: 0.9326 - val_loss: 0.0408 - val_precision: 0.7778 - val_recall: 0.6667
# Epoch 44/50
# 8/8 - 11s - 1s/step - accuracy: 0.9727 - auc: 0.9842 - loss: 0.0072 - precision: 0.9375 - recall: 0.9524 - val_accuracy: 0.8721 - val_auc: 0.9418 - val_loss: 0.0400 - val_precision: 0.7778 - val_recall: 0.6667
# Epoch 45/50
# 8/8 - 20s - 3s/step - accuracy: 0.9609 - auc: 0.9816 - loss: 0.0098 - precision: 0.9344 - recall: 0.9048 - val_accuracy: 0.9186 - val_auc: 0.9491 - val_loss: 0.0411 - val_precision: 0.8182 - val_recall: 0.8571
# 2/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# WARNING:tensorflow:5 out of the last 38 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ff13a8cc820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step
#
# Processing sample: nanopore_SRR21492156
# var_filt shape: (2888, 3836) ref_filt shape: (2888, 3836) target_filt shape: (2888, 2)
# Epoch 1/50
# 55/55 - 40s - 721ms/step - accuracy: 0.6478 - auc: 0.6830 - loss: 0.0846 - precision: 0.2993 - recall: 0.6119 - val_accuracy: 0.8270 - val_auc: 0.7400 - val_loss: 0.0884 - val_precision: 0.9286 - val_recall: 0.1161
# Epoch 2/50
# 55/55 - 41s - 738ms/step - accuracy: 0.7535 - auc: 0.7421 - loss: 0.0469 - precision: 0.4030 - recall: 0.5701 - val_accuracy: 0.3841 - val_auc: 0.4952 - val_loss: 0.2105 - val_precision: 0.1935 - val_recall: 0.6875
# Epoch 3/50
# 55/55 - 33s - 603ms/step - accuracy: 0.8112 - auc: 0.8236 - loss: 0.0357 - precision: 0.5101 - recall: 0.6060 - val_accuracy: 0.8772 - val_auc: 0.8210 - val_loss: 0.0315 - val_precision: 0.7470 - val_recall: 0.5536
# Epoch 4/50
# 55/55 - 40s - 730ms/step - accuracy: 0.8718 - auc: 0.8962 - loss: 0.0270 - precision: 0.6540 - recall: 0.7164 - val_accuracy: 0.8720 - val_auc: 0.8946 - val_loss: 0.0275 - val_precision: 0.8167 - val_recall: 0.4375
# Epoch 5/50
# 55/55 - 43s - 787ms/step - accuracy: 0.8880 - auc: 0.9054 - loss: 0.0246 - precision: 0.7092 - recall: 0.7134 - val_accuracy: 0.8824 - val_auc: 0.9052 - val_loss: 0.0267 - val_precision: 0.8056 - val_recall: 0.5179
# Epoch 6/50
# 55/55 - 39s - 707ms/step - accuracy: 0.9140 - auc: 0.9443 - loss: 0.0188 - precision: 0.7555 - recall: 0.8209 - val_accuracy: 0.8927 - val_auc: 0.9050 - val_loss: 0.0250 - val_precision: 0.8676 - val_recall: 0.5268
# Epoch 7/50
# 55/55 - 41s - 746ms/step - accuracy: 0.9088 - auc: 0.9494 - loss: 0.0176 - precision: 0.7465 - recall: 0.8000 - val_accuracy: 0.8685 - val_auc: 0.8880 - val_loss: 0.0281 - val_precision: 0.8462 - val_recall: 0.3929
# Epoch 8/50
# 55/55 - 41s - 744ms/step - accuracy: 0.9117 - auc: 0.9535 - loss: 0.0167 - precision: 0.7676 - recall: 0.7791 - val_accuracy: 0.8841 - val_auc: 0.9138 - val_loss: 0.0241 - val_precision: 0.8169 - val_recall: 0.5179
# Epoch 9/50
# 55/55 - 43s - 781ms/step - accuracy: 0.9296 - auc: 0.9665 - loss: 0.0131 - precision: 0.8142 - recall: 0.8239 - val_accuracy: 0.8927 - val_auc: 0.9206 - val_loss: 0.0235 - val_precision: 0.8049 - val_recall: 0.5893
# Epoch 10/50
# 55/55 - 43s - 775ms/step - accuracy: 0.9411 - auc: 0.9693 - loss: 0.0120 - precision: 0.8437 - recall: 0.8537 - val_accuracy: 0.8945 - val_auc: 0.9066 - val_loss: 0.0220 - val_precision: 0.7525 - val_recall: 0.6786
# Epoch 11/50
# 55/55 - 40s - 719ms/step - accuracy: 0.9371 - auc: 0.9712 - loss: 0.0131 - precision: 0.8424 - recall: 0.8299 - val_accuracy: 0.8927 - val_auc: 0.9092 - val_loss: 0.0266 - val_precision: 0.7778 - val_recall: 0.6250
# Epoch 12/50
# 55/55 - 41s - 744ms/step - accuracy: 0.9503 - auc: 0.9795 - loss: 0.0097 - precision: 0.8716 - recall: 0.8716 - val_accuracy: 0.8910 - val_auc: 0.9044 - val_loss: 0.0271 - val_precision: 0.7634 - val_recall: 0.6339
# Epoch 13/50
# 55/55 - 41s - 746ms/step - accuracy: 0.9498 - auc: 0.9821 - loss: 0.0095 - precision: 0.8827 - recall: 0.8537 - val_accuracy: 0.8945 - val_auc: 0.9087 - val_loss: 0.0250 - val_precision: 0.7684 - val_recall: 0.6518
# Epoch 14/50
# 55/55 - 44s - 800ms/step - accuracy: 0.9567 - auc: 0.9842 - loss: 0.0090 - precision: 0.8892 - recall: 0.8866 - val_accuracy: 0.8927 - val_auc: 0.9013 - val_loss: 0.0277 - val_precision: 0.7907 - val_recall: 0.6071
# Epoch 15/50
# 55/55 - 37s - 679ms/step - accuracy: 0.9642 - auc: 0.9859 - loss: 0.0082 - precision: 0.9003 - recall: 0.9164 - val_accuracy: 0.8806 - val_auc: 0.8905 - val_loss: 0.0259 - val_precision: 0.7722 - val_recall: 0.5446
# Epoch 16/50
# 55/55 - 41s - 737ms/step - accuracy: 0.9521 - auc: 0.9875 - loss: 0.0081 - precision: 0.8750 - recall: 0.8776 - val_accuracy: 0.8754 - val_auc: 0.8884 - val_loss: 0.0295 - val_precision: 0.7703 - val_recall: 0.5089
# Epoch 17/50
# 55/55 - 40s - 730ms/step - accuracy: 0.9567 - auc: 0.9822 - loss: 0.0097 - precision: 0.8892 - recall: 0.8866 - val_accuracy: 0.8685 - val_auc: 0.8846 - val_loss: 0.0288 - val_precision: 0.7143 - val_recall: 0.5357
# Epoch 18/50
# 55/55 - 42s - 769ms/step - accuracy: 0.9440 - auc: 0.9778 - loss: 0.0104 - precision: 0.8696 - recall: 0.8358 - val_accuracy: 0.8789 - val_auc: 0.8757 - val_loss: 0.0320 - val_precision: 0.7100 - val_recall: 0.6339
# Epoch 19/50
# 55/55 - 40s - 726ms/step - accuracy: 0.9555 - auc: 0.9852 - loss: 0.0091 - precision: 0.8862 - recall: 0.8836 - val_accuracy: 0.8875 - val_auc: 0.8872 - val_loss: 0.0264 - val_precision: 0.7156 - val_recall: 0.6964
# Epoch 20/50
# 55/55 - 41s - 745ms/step - accuracy: 0.9555 - auc: 0.9843 - loss: 0.0091 - precision: 0.8772 - recall: 0.8955 - val_accuracy: 0.8858 - val_auc: 0.8948 - val_loss: 0.0285 - val_precision: 0.7347 - val_recall: 0.6429
# WARNING:tensorflow:6 out of the last 39 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ff13db5d1b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step
# Epoch 1/50
# 55/55 - 39s - 702ms/step - accuracy: 0.6501 - auc: 0.6677 - loss: 0.0840 - precision: 0.3010 - recall: 0.6119 - val_accuracy: 0.3080 - val_auc: 0.6470 - val_loss: 0.4386 - val_precision: 0.2131 - val_recall: 0.9554
# Epoch 2/50
# 55/55 - 43s - 773ms/step - accuracy: 0.7714 - auc: 0.7447 - loss: 0.0466 - precision: 0.4289 - recall: 0.5493 - val_accuracy: 0.4983 - val_auc: 0.7619 - val_loss: 0.0970 - val_precision: 0.2694 - val_recall: 0.9286
# Epoch 3/50
# 55/55 - 39s - 709ms/step - accuracy: 0.8308 - auc: 0.8315 - loss: 0.0367 - precision: 0.5536 - recall: 0.6478 - val_accuracy: 0.8754 - val_auc: 0.8905 - val_loss: 0.0301 - val_precision: 0.7564 - val_recall: 0.5268
# Epoch 4/50
# 55/55 - 41s - 745ms/step - accuracy: 0.8759 - auc: 0.8814 - loss: 0.0283 - precision: 0.6734 - recall: 0.6955 - val_accuracy: 0.8997 - val_auc: 0.9096 - val_loss: 0.0199 - val_precision: 0.8553 - val_recall: 0.5804
# Epoch 5/50
# 55/55 - 40s - 729ms/step - accuracy: 0.8863 - auc: 0.8974 - loss: 0.0260 - precision: 0.6994 - recall: 0.7224 - val_accuracy: 0.8997 - val_auc: 0.9273 - val_loss: 0.0188 - val_precision: 0.8462 - val_recall: 0.5893
# Epoch 6/50
# 55/55 - 41s - 751ms/step - accuracy: 0.8932 - auc: 0.9168 - loss: 0.0229 - precision: 0.7143 - recall: 0.7463 - val_accuracy: 0.8927 - val_auc: 0.9290 - val_loss: 0.0194 - val_precision: 0.7976 - val_recall: 0.5982
# Epoch 7/50
# 55/55 - 33s - 599ms/step - accuracy: 0.9151 - auc: 0.9311 - loss: 0.0195 - precision: 0.7956 - recall: 0.7552 - val_accuracy: 0.8841 - val_auc: 0.8915 - val_loss: 0.0293 - val_precision: 0.7528 - val_recall: 0.5982
# Epoch 8/50
# 55/55 - 41s - 742ms/step - accuracy: 0.9186 - auc: 0.9487 - loss: 0.0170 - precision: 0.7853 - recall: 0.7970 - val_accuracy: 0.9118 - val_auc: 0.9335 - val_loss: 0.0212 - val_precision: 0.8506 - val_recall: 0.6607
# Epoch 9/50
# 55/55 - 43s - 779ms/step - accuracy: 0.9365 - auc: 0.9672 - loss: 0.0136 - precision: 0.8280 - recall: 0.8478 - val_accuracy: 0.8927 - val_auc: 0.9254 - val_loss: 0.0225 - val_precision: 0.8571 - val_recall: 0.5357
# Epoch 10/50
# 55/55 - 40s - 720ms/step - accuracy: 0.9244 - auc: 0.9524 - loss: 0.0171 - precision: 0.8054 - recall: 0.8030 - val_accuracy: 0.9135 - val_auc: 0.9277 - val_loss: 0.0171 - val_precision: 0.8298 - val_recall: 0.6964
# Epoch 11/50
# 55/55 - 33s - 598ms/step - accuracy: 0.9267 - auc: 0.9658 - loss: 0.0131 - precision: 0.8059 - recall: 0.8179 - val_accuracy: 0.9083 - val_auc: 0.9302 - val_loss: 0.0185 - val_precision: 0.7757 - val_recall: 0.7411
# Epoch 12/50
# 55/55 - 42s - 762ms/step - accuracy: 0.9376 - auc: 0.9610 - loss: 0.0136 - precision: 0.8348 - recall: 0.8448 - val_accuracy: 0.9187 - val_auc: 0.9286 - val_loss: 0.0168 - val_precision: 0.7982 - val_recall: 0.7768
# Epoch 13/50
# 55/55 - 41s - 741ms/step - accuracy: 0.9400 - auc: 0.9727 - loss: 0.0117 - precision: 0.8367 - recall: 0.8567 - val_accuracy: 0.9204 - val_auc: 0.9317 - val_loss: 0.0170 - val_precision: 0.8235 - val_recall: 0.7500
# Epoch 14/50
# 55/55 - 33s - 608ms/step - accuracy: 0.9428 - auc: 0.9763 - loss: 0.0113 - precision: 0.8391 - recall: 0.8716 - val_accuracy: 0.8910 - val_auc: 0.9136 - val_loss: 0.0246 - val_precision: 0.7526 - val_recall: 0.6518
# Epoch 15/50
# 55/55 - 41s - 743ms/step - accuracy: 0.9440 - auc: 0.9753 - loss: 0.0107 - precision: 0.8563 - recall: 0.8537 - val_accuracy: 0.9152 - val_auc: 0.9386 - val_loss: 0.0170 - val_precision: 0.8247 - val_recall: 0.7143
# Epoch 16/50
# 55/55 - 41s - 740ms/step - accuracy: 0.9475 - auc: 0.9730 - loss: 0.0108 - precision: 0.8836 - recall: 0.8388 - val_accuracy: 0.9100 - val_auc: 0.9380 - val_loss: 0.0183 - val_precision: 0.8659 - val_recall: 0.6339
# Epoch 17/50
# 55/55 - 42s - 760ms/step - accuracy: 0.9532 - auc: 0.9761 - loss: 0.0105 - precision: 0.8713 - recall: 0.8896 - val_accuracy: 0.8945 - val_auc: 0.9158 - val_loss: 0.0257 - val_precision: 0.9180 - val_recall: 0.5000
# Epoch 18/50
# 55/55 - 40s - 729ms/step - accuracy: 0.9498 - auc: 0.9846 - loss: 0.0083 - precision: 0.8924 - recall: 0.8418 - val_accuracy: 0.9031 - val_auc: 0.9341 - val_loss: 0.0205 - val_precision: 0.8111 - val_recall: 0.6518
# Epoch 19/50
# 55/55 - 41s - 744ms/step - accuracy: 0.9607 - auc: 0.9895 - loss: 0.0072 - precision: 0.8915 - recall: 0.9075 - val_accuracy: 0.8875 - val_auc: 0.9352 - val_loss: 0.0241 - val_precision: 0.8730 - val_recall: 0.4911
# Epoch 20/50
# 55/55 - 41s - 748ms/step - accuracy: 0.9648 - auc: 0.9919 - loss: 0.0062 - precision: 0.9152 - recall: 0.9015 - val_accuracy: 0.9100 - val_auc: 0.9309 - val_loss: 0.0239 - val_precision: 0.8261 - val_recall: 0.6786
# Epoch 21/50
# 55/55 - 33s - 599ms/step - accuracy: 0.9706 - auc: 0.9933 - loss: 0.0057 - precision: 0.9251 - recall: 0.9224 - val_accuracy: 0.9048 - val_auc: 0.9259 - val_loss: 0.0239 - val_precision: 0.7822 - val_recall: 0.7054
# Epoch 22/50
# 55/55 - 42s - 761ms/step - accuracy: 0.9584 - auc: 0.9868 - loss: 0.0075 - precision: 0.9046 - recall: 0.8776 - val_accuracy: 0.9048 - val_auc: 0.9213 - val_loss: 0.0237 - val_precision: 0.7879 - val_recall: 0.6964
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
#
# Processing sample: nanopore_SRR21492157
# var_filt shape: (5434, 4138) ref_filt shape: (5434, 4138) target_filt shape: (5434, 2)
# Epoch 1/50
# 102/102 - 75s - 737ms/step - accuracy: 0.6543 - auc: 0.6068 - loss: 0.0813 - precision: 0.2774 - recall: 0.4674 - val_accuracy: 0.8445 - val_auc: 0.7795 - val_loss: 0.0343 - val_precision: 0.6223 - val_recall: 0.5442
# Epoch 2/50
# 102/102 - 78s - 768ms/step - accuracy: 0.7479 - auc: 0.6949 - loss: 0.0464 - precision: 0.3813 - recall: 0.4441 - val_accuracy: 0.8316 - val_auc: 0.8229 - val_loss: 0.0283 - val_precision: 0.7162 - val_recall: 0.2465
# Epoch 3/50
# 102/102 - 65s - 634ms/step - accuracy: 0.8031 - auc: 0.7992 - loss: 0.0353 - precision: 0.5015 - recall: 0.5295 - val_accuracy: 0.8500 - val_auc: 0.8516 - val_loss: 0.0245 - val_precision: 0.8333 - val_recall: 0.3023
# Epoch 4/50
# 102/102 - 83s - 815ms/step - accuracy: 0.8270 - auc: 0.8428 - loss: 0.0296 - precision: 0.5645 - recall: 0.5435 - val_accuracy: 0.8381 - val_auc: 0.8367 - val_loss: 0.0245 - val_precision: 0.7600 - val_recall: 0.2651
# Epoch 5/50
# 102/102 - 82s - 805ms/step - accuracy: 0.8632 - auc: 0.8888 - loss: 0.0240 - precision: 0.6581 - recall: 0.6398 - val_accuracy: 0.8721 - val_auc: 0.8270 - val_loss: 0.0249 - val_precision: 0.8333 - val_recall: 0.4419
# Epoch 6/50
# 102/102 - 81s - 792ms/step - accuracy: 0.8880 - auc: 0.9246 - loss: 0.0189 - precision: 0.7190 - recall: 0.7112 - val_accuracy: 0.8611 - val_auc: 0.8749 - val_loss: 0.0218 - val_precision: 0.7623 - val_recall: 0.4326
# Epoch 7/50
# 102/102 - 81s - 798ms/step - accuracy: 0.8954 - auc: 0.9253 - loss: 0.0186 - precision: 0.7555 - recall: 0.6957 - val_accuracy: 0.8694 - val_auc: 0.8774 - val_loss: 0.0232 - val_precision: 0.7967 - val_recall: 0.4558
# Epoch 8/50
# 102/102 - 82s - 803ms/step - accuracy: 0.9120 - auc: 0.9479 - loss: 0.0153 - precision: 0.7874 - recall: 0.7593 - val_accuracy: 0.8537 - val_auc: 0.8535 - val_loss: 0.0268 - val_precision: 0.7090 - val_recall: 0.4419
# Epoch 9/50
# 102/102 - 84s - 827ms/step - accuracy: 0.9221 - auc: 0.9581 - loss: 0.0136 - precision: 0.8197 - recall: 0.7764 - val_accuracy: 0.8648 - val_auc: 0.8467 - val_loss: 0.0265 - val_precision: 0.7537 - val_recall: 0.4698
# Epoch 10/50
# 102/102 - 83s - 809ms/step - accuracy: 0.9224 - auc: 0.9641 - loss: 0.0125 - precision: 0.8138 - recall: 0.7873 - val_accuracy: 0.8583 - val_auc: 0.8444 - val_loss: 0.0266 - val_precision: 0.6723 - val_recall: 0.5535
# Epoch 11/50
# 102/102 - 82s - 804ms/step - accuracy: 0.9252 - auc: 0.9609 - loss: 0.0131 - precision: 0.8268 - recall: 0.7857 - val_accuracy: 0.8546 - val_auc: 0.8676 - val_loss: 0.0252 - val_precision: 0.7317 - val_recall: 0.4186
# Epoch 12/50
# 102/102 - 82s - 803ms/step - accuracy: 0.9390 - auc: 0.9739 - loss: 0.0105 - precision: 0.8630 - recall: 0.8214 - val_accuracy: 0.8675 - val_auc: 0.8482 - val_loss: 0.0313 - val_precision: 0.8087 - val_recall: 0.4326
# Epoch 13/50
# 102/102 - 67s - 656ms/step - accuracy: 0.9417 - auc: 0.9742 - loss: 0.0108 - precision: 0.8673 - recall: 0.8323 - val_accuracy: 0.8749 - val_auc: 0.8572 - val_loss: 0.0275 - val_precision: 0.7687 - val_recall: 0.5256
# Epoch 14/50
# 102/102 - 82s - 803ms/step - accuracy: 0.9417 - auc: 0.9756 - loss: 0.0105 - precision: 0.8783 - recall: 0.8183 - val_accuracy: 0.8574 - val_auc: 0.8712 - val_loss: 0.0242 - val_precision: 0.7239 - val_recall: 0.4512
# Epoch 15/50
# 102/102 - 70s - 683ms/step - accuracy: 0.9482 - auc: 0.9818 - loss: 0.0088 - precision: 0.8764 - recall: 0.8587 - val_accuracy: 0.8758 - val_auc: 0.8764 - val_loss: 0.0260 - val_precision: 0.8030 - val_recall: 0.4930
# Epoch 16/50
# 102/102 - 82s - 805ms/step - accuracy: 0.9429 - auc: 0.9771 - loss: 0.0099 - precision: 0.8730 - recall: 0.8323 - val_accuracy: 0.8620 - val_auc: 0.8807 - val_loss: 0.0256 - val_precision: 0.6349 - val_recall: 0.7116
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step
# Epoch 1/50
# 102/102 - 77s - 757ms/step - accuracy: 0.6571 - auc: 0.6171 - loss: 0.0772 - precision: 0.2838 - recall: 0.4829 - val_accuracy: 0.5115 - val_auc: 0.5744 - val_loss: 0.0576 - val_precision: 0.2106 - val_recall: 0.5349
# Epoch 2/50
# 102/102 - 81s - 796ms/step - accuracy: 0.7580 - auc: 0.7140 - loss: 0.0452 - precision: 0.3939 - recall: 0.4177 - val_accuracy: 0.8482 - val_auc: 0.7638 - val_loss: 0.0335 - val_precision: 0.7551 - val_recall: 0.3442
# Epoch 3/50
# 102/102 - 82s - 800ms/step - accuracy: 0.8196 - auc: 0.8278 - loss: 0.0307 - precision: 0.5431 - recall: 0.5481 - val_accuracy: 0.8537 - val_auc: 0.8237 - val_loss: 0.0263 - val_precision: 0.6707 - val_recall: 0.5116
# Epoch 4/50
# 102/102 - 70s - 688ms/step - accuracy: 0.8494 - auc: 0.8650 - loss: 0.0265 - precision: 0.6244 - recall: 0.5963 - val_accuracy: 0.8648 - val_auc: 0.8564 - val_loss: 0.0236 - val_precision: 0.7576 - val_recall: 0.4651
# Epoch 5/50
# 102/102 - 81s - 797ms/step - accuracy: 0.8791 - auc: 0.9132 - loss: 0.0209 - precision: 0.6997 - recall: 0.6801 - val_accuracy: 0.8730 - val_auc: 0.8676 - val_loss: 0.0231 - val_precision: 0.7895 - val_recall: 0.4884
# Epoch 6/50
# 102/102 - 82s - 805ms/step - accuracy: 0.8896 - auc: 0.9318 - loss: 0.0173 - precision: 0.7276 - recall: 0.7050 - val_accuracy: 0.8721 - val_auc: 0.8557 - val_loss: 0.0249 - val_precision: 0.8167 - val_recall: 0.4558
# Epoch 7/50
# 102/102 - 81s - 797ms/step - accuracy: 0.9061 - auc: 0.9438 - loss: 0.0159 - precision: 0.7780 - recall: 0.7345 - val_accuracy: 0.8629 - val_auc: 0.8501 - val_loss: 0.0270 - val_precision: 0.8300 - val_recall: 0.3860
# Epoch 8/50
# 102/102 - 80s - 784ms/step - accuracy: 0.9015 - auc: 0.9439 - loss: 0.0158 - precision: 0.7652 - recall: 0.7236 - val_accuracy: 0.8565 - val_auc: 0.8377 - val_loss: 0.0255 - val_precision: 0.6561 - val_recall: 0.5767
# Epoch 9/50
# 102/102 - 81s - 797ms/step - accuracy: 0.9239 - auc: 0.9629 - loss: 0.0132 - precision: 0.8356 - recall: 0.7655 - val_accuracy: 0.8592 - val_auc: 0.8429 - val_loss: 0.0255 - val_precision: 0.6890 - val_recall: 0.5256
# Epoch 10/50
# 102/102 - 83s - 815ms/step - accuracy: 0.9316 - auc: 0.9657 - loss: 0.0123 - precision: 0.8390 - recall: 0.8090 - val_accuracy: 0.8574 - val_auc: 0.8450 - val_loss: 0.0257 - val_precision: 0.7000 - val_recall: 0.4884
# Epoch 11/50
# 102/102 - 80s - 782ms/step - accuracy: 0.9331 - auc: 0.9684 - loss: 0.0117 - precision: 0.8550 - recall: 0.7966 - val_accuracy: 0.8519 - val_auc: 0.8495 - val_loss: 0.0270 - val_precision: 0.6436 - val_recall: 0.5628
# Epoch 12/50
# 102/102 - 82s - 801ms/step - accuracy: 0.9393 - auc: 0.9731 - loss: 0.0109 - precision: 0.8692 - recall: 0.8152 - val_accuracy: 0.8491 - val_auc: 0.8279 - val_loss: 0.0299 - val_precision: 0.6393 - val_recall: 0.5442
# Epoch 13/50
# 102/102 - 84s - 823ms/step - accuracy: 0.9399 - auc: 0.9744 - loss: 0.0106 - precision: 0.8696 - recall: 0.8183 - val_accuracy: 0.8528 - val_auc: 0.8406 - val_loss: 0.0304 - val_precision: 0.7723 - val_recall: 0.3628
# Epoch 14/50
# 102/102 - 81s - 797ms/step - accuracy: 0.9411 - auc: 0.9743 - loss: 0.0108 - precision: 0.8693 - recall: 0.8261 - val_accuracy: 0.8537 - val_auc: 0.8490 - val_loss: 0.0295 - val_precision: 0.7414 - val_recall: 0.4000
# Epoch 15/50
# 102/102 - 66s - 647ms/step - accuracy: 0.9359 - auc: 0.9751 - loss: 0.0105 - precision: 0.8595 - recall: 0.8075 - val_accuracy: 0.8666 - val_auc: 0.8496 - val_loss: 0.0294 - val_precision: 0.8125 - val_recall: 0.4233
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 4s 116ms/step
#
# Processing sample: nanopore_SRR21492158
# var_filt shape: (1495, 5482) ref_filt shape: (1495, 5482) target_filt shape: (1495, 2)
# Epoch 1/50
# 29/29 - 32s - 1s/step - accuracy: 0.6254 - auc: 0.6685 - loss: 0.0990 - precision: 0.2580 - recall: 0.6299 - val_accuracy: 0.2676 - val_auc: 0.5661 - val_loss: 1.9172 - val_precision: 0.1919 - val_recall: 1.0000
# Epoch 2/50
# 29/29 - 37s - 1s/step - accuracy: 0.6890 - auc: 0.6731 - loss: 0.0681 - precision: 0.2822 - recall: 0.5260 - val_accuracy: 0.8896 - val_auc: 0.8142 - val_loss: 0.1468 - val_precision: 0.7317 - val_recall: 0.5769
# Epoch 3/50
# 29/29 - 40s - 1s/step - accuracy: 0.7492 - auc: 0.7108 - loss: 0.0567 - precision: 0.3527 - recall: 0.5519 - val_accuracy: 0.3010 - val_auc: 0.5751 - val_loss: 0.7672 - val_precision: 0.1969 - val_recall: 0.9808
# Epoch 4/50
# 29/29 - 43s - 1s/step - accuracy: 0.7848 - auc: 0.6981 - loss: 0.0488 - precision: 0.3934 - recall: 0.4675 - val_accuracy: 0.8763 - val_auc: 0.8569 - val_loss: 0.0950 - val_precision: 0.6829 - val_recall: 0.5385
# Epoch 5/50
# 29/29 - 24s - 845ms/step - accuracy: 0.7993 - auc: 0.7316 - loss: 0.0447 - precision: 0.4207 - recall: 0.4481 - val_accuracy: 0.8395 - val_auc: 0.7770 - val_loss: 0.0329 - val_precision: 0.6250 - val_recall: 0.1923
# Epoch 6/50
# 29/29 - 39s - 1s/step - accuracy: 0.8216 - auc: 0.7513 - loss: 0.0395 - precision: 0.4810 - recall: 0.4935 - val_accuracy: 0.8963 - val_auc: 0.9132 - val_loss: 0.0411 - val_precision: 0.7442 - val_recall: 0.6154
# Epoch 7/50
# 29/29 - 41s - 1s/step - accuracy: 0.8272 - auc: 0.8097 - loss: 0.0350 - precision: 0.4971 - recall: 0.5649 - val_accuracy: 0.8863 - val_auc: 0.9198 - val_loss: 0.0400 - val_precision: 0.6286 - val_recall: 0.8462
# Epoch 8/50
# ...
# Epoch 19/50
# 29/29 - 41s - 1s/step - accuracy: 0.9376 - auc: 0.9645 - loss: 0.0144 - precision: 0.7988 - recall: 0.8506 - val_accuracy: 0.9164 - val_auc: 0.9056 - val_loss: 0.0203 - val_precision: 0.7647 - val_recall: 0.7500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step
#
# Processing sample: nanopore_SRR21492159
# var_filt shape: (1820, 5916) ref_filt shape: (1820, 5916) target_filt shape: (1820, 2)
# Epoch 1/50
# 35/35 - 38s - 1s/step - accuracy: 0.5733 - auc: 0.5756 - loss: 0.0977 - precision: 0.0909 - recall: 0.5443 - val_accuracy: 0.2033 - val_auc: 0.5242 - val_loss: 1.0318 - val_precision: 0.0825 - val_recall: 0.9630
# Epoch 2/50
# 35/35 - 39s - 1s/step - accuracy: 0.7005 - auc: 0.6028 - loss: 0.0553 - precision: 0.1101 - recall: 0.4430 - val_accuracy: 0.1841 - val_auc: 0.5084 - val_loss: 1.1964 - val_precision: 0.0728 - val_recall: 0.8519
# Epoch 3/50
# 35/35 - 41s - 1s/step - accuracy: 0.7930 - auc: 0.7037 - loss: 0.0360 - precision: 0.1581 - recall: 0.4304 - val_accuracy: 0.3654 - val_auc: 0.6439 - val_loss: 0.3593 - val_precision: 0.0854 - val_recall: 0.7778
# Epoch 4/50
# 35/35 - 41s - 1s/step - accuracy: 0.8443 - auc: 0.6285 - loss: 0.0333 - precision: 0.1630 - recall: 0.2785 - val_accuracy: 0.3764 - val_auc: 0.3134 - val_loss: 0.4660 - val_precision: 0.0283 - val_recall: 0.2222
# Epoch 5/50
# 35/35 - 41s - 1s/step - accuracy: 0.8599 - auc: 0.6735 - loss: 0.0273 - precision: 0.1696 - recall: 0.2405 - val_accuracy: 0.5659 - val_auc: 0.6042 - val_loss: 0.1066 - val_precision: 0.0719 - val_recall: 0.4074
# Epoch 6/50
# 35/35 - 42s - 1s/step - accuracy: 0.8736 - auc: 0.6970 - loss: 0.0278 - precision: 0.2342 - recall: 0.3291 - val_accuracy: 0.6978 - val_auc: 0.6361 - val_loss: 0.0423 - val_precision: 0.0808 - val_recall: 0.2963
# Epoch 7/50
# 35/35 - 33s - 954ms/step - accuracy: 0.8864 - auc: 0.7068 - loss: 0.0262 - precision: 0.2680 - recall: 0.3291 - val_accuracy: 0.8846 - val_auc: 0.8267 - val_loss: 0.0270 - val_precision: 0.2727 - val_recall: 0.3333
# Epoch 8/50
# 35/35 - 40s - 1s/step - accuracy: 0.8929 - auc: 0.7199 - loss: 0.0237 - precision: 0.2889 - recall: 0.3291 - val_accuracy: 0.8571 - val_auc: 0.8226 - val_loss: 0.0401 - val_precision: 0.2340 - val_recall: 0.4074
# Epoch 9/50
# 35/35 - 40s - 1s/step - accuracy: 0.9158 - auc: 0.7683 - loss: 0.0202 - precision: 0.4133 - recall: 0.3924 - val_accuracy: 0.9231 - val_auc: 0.8499 - val_loss: 0.0421 - val_precision: 0.4828 - val_recall: 0.5185
# Epoch 10/50
# 35/35 - 32s - 913ms/step - accuracy: 0.9167 - auc: 0.8131 - loss: 0.0191 - precision: 0.4091 - recall: 0.3418 - val_accuracy: 0.9203 - val_auc: 0.8898 - val_loss: 0.0196 - val_precision: 0.4545 - val_recall: 0.3704
# Epoch 11/50
# 35/35 - 41s - 1s/step - accuracy: 0.8993 - auc: 0.8027 - loss: 0.0211 - precision: 0.3176 - recall: 0.3418 - val_accuracy: 0.9396 - val_auc: 0.9315 - val_loss: 0.0150 - val_precision: 0.6667 - val_recall: 0.3704
# Epoch 12/50
# 35/35 - 41s - 1s/step - accuracy: 0.9103 - auc: 0.8071 - loss: 0.0188 - precision: 0.3797 - recall: 0.3797 - val_accuracy: 0.9533 - val_auc: 0.9577 - val_loss: 0.0163 - val_precision: 0.7500 - val_recall: 0.5556
# Epoch 13/50
# 35/35 - 40s - 1s/step - accuracy: 0.9130 - auc: 0.8001 - loss: 0.0180 - precision: 0.3857 - recall: 0.3418 - val_accuracy: 0.9286 - val_auc: 0.9375 - val_loss: 0.0107 - val_precision: 0.6000 - val_recall: 0.1111
# Epoch 14/50
# 35/35 - 42s - 1s/step - accuracy: 0.9176 - auc: 0.8104 - loss: 0.0184 - precision: 0.4267 - recall: 0.4051 - val_accuracy: 0.9286 - val_auc: 0.9341 - val_loss: 0.0112 - val_precision: 0.5455 - val_recall: 0.2222
# Epoch 15/50
# 35/35 - 41s - 1s/step - accuracy: 0.9139 - auc: 0.8385 - loss: 0.0196 - precision: 0.3973 - recall: 0.3671 - val_accuracy: 0.9258 - val_auc: 0.8870 - val_loss: 0.0143 - val_precision: 0.5000 - val_recall: 0.0741
# Epoch 16/50
# 35/35 - 41s - 1s/step - accuracy: 0.9295 - auc: 0.8740 - loss: 0.0178 - precision: 0.5135 - recall: 0.4810 - val_accuracy: 0.9148 - val_auc: 0.8835 - val_loss: 0.0145 - val_precision: 0.3333 - val_recall: 0.1481
# Epoch 17/50
# 35/35 - 41s - 1s/step - accuracy: 0.9258 - auc: 0.8365 - loss: 0.0171 - precision: 0.4821 - recall: 0.3418 - val_accuracy: 0.9313 - val_auc: 0.9224 - val_loss: 0.0112 - val_precision: 0.5833 - val_recall: 0.2593
# Epoch 18/50
# 35/35 - 41s - 1s/step - accuracy: 0.9350 - auc: 0.9251 - loss: 0.0130 - precision: 0.5455 - recall: 0.6076 - val_accuracy: 0.9313 - val_auc: 0.9549 - val_loss: 0.0101 - val_precision: 0.6667 - val_recall: 0.1481
# Epoch 19/50
# 35/35 - 40s - 1s/step - accuracy: 0.9451 - auc: 0.9022 - loss: 0.0110 - precision: 0.6377 - recall: 0.5570 - val_accuracy: 0.9368 - val_auc: 0.9427 - val_loss: 0.0126 - val_precision: 0.6667 - val_recall: 0.2963
# Epoch 20/50
# 35/35 - 42s - 1s/step - accuracy: 0.9405 - auc: 0.9056 - loss: 0.0120 - precision: 0.6000 - recall: 0.5316 - val_accuracy: 0.9423 - val_auc: 0.9620 - val_loss: 0.0138 - val_precision: 0.6875 - val_recall: 0.4074
# Epoch 21/50
# 35/35 - 40s - 1s/step - accuracy: 0.9341 - auc: 0.9109 - loss: 0.0128 - precision: 0.5402 - recall: 0.5949 - val_accuracy: 0.9368 - val_auc: 0.9191 - val_loss: 0.0141 - val_precision: 0.6429 - val_recall: 0.3333
# Epoch 22/50
# 35/35 - 32s - 923ms/step - accuracy: 0.9469 - auc: 0.9270 - loss: 0.0107 - precision: 0.6438 - recall: 0.5949 - val_accuracy: 0.9258 - val_auc: 0.8994 - val_loss: 0.0132 - val_precision: 0.5000 - val_recall: 0.0741
# Epoch 23/50
# 35/35 - 41s - 1s/step - accuracy: 0.9487 - auc: 0.9432 - loss: 0.0097 - precision: 0.6716 - recall: 0.5696 - val_accuracy: 0.9368 - val_auc: 0.9098 - val_loss: 0.0146 - val_precision: 0.6667 - val_recall: 0.2963
# Epoch 24/50
# 35/35 - 42s - 1s/step - accuracy: 0.9487 - auc: 0.9534 - loss: 0.0092 - precision: 0.6456 - recall: 0.6456 - val_accuracy: 0.9368 - val_auc: 0.9587 - val_loss: 0.0114 - val_precision: 0.7500 - val_recall: 0.2222
# Epoch 25/50
# 35/35 - 40s - 1s/step - accuracy: 0.9533 - auc: 0.9426 - loss: 0.0098 - precision: 0.6944 - recall: 0.6329 - val_accuracy: 0.9451 - val_auc: 0.9449 - val_loss: 0.0119 - val_precision: 0.6842 - val_recall: 0.4815
# Epoch 26/50
# 35/35 - 42s - 1s/step - accuracy: 0.9542 - auc: 0.9294 - loss: 0.0096 - precision: 0.7302 - recall: 0.5823 - val_accuracy: 0.9423 - val_auc: 0.9608 - val_loss: 0.0116 - val_precision: 0.6875 - val_recall: 0.4074
# Epoch 27/50
# 35/35 - 41s - 1s/step - accuracy: 0.9432 - auc: 0.9538 - loss: 0.0097 - precision: 0.5977 - recall: 0.6582 - val_accuracy: 0.9505 - val_auc: 0.9578 - val_loss: 0.0092 - val_precision: 0.6957 - val_recall: 0.5926
# Epoch 28/50
# 35/35 - 41s - 1s/step - accuracy: 0.9588 - auc: 0.9663 - loss: 0.0075 - precision: 0.7237 - recall: 0.6962 - val_accuracy: 0.9533 - val_auc: 0.9598 - val_loss: 0.0093 - val_precision: 0.7500 - val_recall: 0.5556
# Epoch 29/50
# 35/35 - 41s - 1s/step - accuracy: 0.9441 - auc: 0.9638 - loss: 0.0083 - precision: 0.6250 - recall: 0.5696 - val_accuracy: 0.9396 - val_auc: 0.9590 - val_loss: 0.0119 - val_precision: 0.6667 - val_recall: 0.3704
# Epoch 30/50
# 35/35 - 40s - 1s/step - accuracy: 0.9432 - auc: 0.9588 - loss: 0.0090 - precision: 0.6269 - recall: 0.5316 - val_accuracy: 0.9451 - val_auc: 0.9358 - val_loss: 0.0135 - val_precision: 0.7333 - val_recall: 0.4074
# Epoch 31/50
# 35/35 - 42s - 1s/step - accuracy: 0.9597 - auc: 0.9777 - loss: 0.0066 - precision: 0.7465 - recall: 0.6709 - val_accuracy: 0.9423 - val_auc: 0.9494 - val_loss: 0.0128 - val_precision: 0.7143 - val_recall: 0.3704
# Epoch 32/50
# 35/35 - 41s - 1s/step - accuracy: 0.9670 - auc: 0.9767 - loss: 0.0063 - precision: 0.7867 - recall: 0.7468 - val_accuracy: 0.9368 - val_auc: 0.9385 - val_loss: 0.0143 - val_precision: 0.6429 - val_recall: 0.3333
# Epoch 33/50
# 35/35 - 40s - 1s/step - accuracy: 0.9625 - auc: 0.9754 - loss: 0.0062 - precision: 0.7317 - recall: 0.7595 - val_accuracy: 0.9396 - val_auc: 0.9533 - val_loss: 0.0112 - val_precision: 0.6667 - val_recall: 0.3704
# Epoch 34/50
# 35/35 - 41s - 1s/step - accuracy: 0.9570 - auc: 0.9648 - loss: 0.0073 - precision: 0.7105 - recall: 0.6835 - val_accuracy: 0.9396 - val_auc: 0.9321 - val_loss: 0.0137 - val_precision: 0.6923 - val_recall: 0.3333
# Epoch 35/50
# 35/35 - 41s - 1s/step - accuracy: 0.9634 - auc: 0.9764 - loss: 0.0064 - precision: 0.7671 - recall: 0.7089 - val_accuracy: 0.9451 - val_auc: 0.9621 - val_loss: 0.0139 - val_precision: 0.7059 - val_recall: 0.4444
# Epoch 36/50
# 35/35 - 42s - 1s/step - accuracy: 0.9661 - auc: 0.9814 - loss: 0.0062 - precision: 0.7838 - recall: 0.7342 - val_accuracy: 0.9478 - val_auc: 0.9166 - val_loss: 0.0188 - val_precision: 0.6538 - val_recall: 0.6296
# Epoch 37/50
# 35/35 - 41s - 1s/step - accuracy: 0.9698 - auc: 0.9881 - loss: 0.0047 - precision: 0.8286 - recall: 0.7342 - val_accuracy: 0.9368 - val_auc: 0.9576 - val_loss: 0.0151 - val_precision: 0.7000 - val_recall: 0.2593
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step
# Epoch 1/50
# 35/35 - 42s - 1s/step - accuracy: 0.5842 - auc: 0.5483 - loss: 0.1234 - precision: 0.0843 - recall: 0.4810 - val_accuracy: 0.0852 - val_auc: 0.4287 - val_loss: 2.6023 - val_precision: 0.0726 - val_recall: 0.9630
# Epoch 2/50
# 35/35 - 40s - 1s/step - accuracy: 0.6722 - auc: 0.5790 - loss: 0.0676 - precision: 0.0957 - recall: 0.4177 - val_accuracy: 0.1951 - val_auc: 0.4412 - val_loss: 1.8006 - val_precision: 0.0682 - val_recall: 0.7778
# Epoch 3/50
# 35/35 - 40s - 1s/step - accuracy: 0.7793 - auc: 0.6024 - loss: 0.0449 - precision: 0.1416 - recall: 0.4051 - val_accuracy: 0.3407 - val_auc: 0.5604 - val_loss: 0.5050 - val_precision: 0.0723 - val_recall: 0.6667
# Epoch 4/50
# 35/35 - 41s - 1s/step - accuracy: 0.8342 - auc: 0.6603 - loss: 0.0366 - precision: 0.1731 - recall: 0.3418 - val_accuracy: 0.3901 - val_auc: 0.5324 - val_loss: 0.4938 - val_precision: 0.0628 - val_recall: 0.5185
# Epoch 5/50
# 35/35 - 42s - 1s/step - accuracy: 0.8700 - auc: 0.7145 - loss: 0.0283 - precision: 0.2520 - recall: 0.4051 - val_accuracy: 0.5330 - val_auc: 0.5922 - val_loss: 0.1418 - val_precision: 0.0769 - val_recall: 0.4815
# Epoch 6/50
# 35/35 - 41s - 1s/step - accuracy: 0.8709 - auc: 0.6053 - loss: 0.0324 - precision: 0.2182 - recall: 0.3038 - val_accuracy: 0.7637 - val_auc: 0.7771 - val_loss: 0.0482 - val_precision: 0.1609 - val_recall: 0.5185
# Epoch 7/50
# 35/35 - 41s - 1s/step - accuracy: 0.8846 - auc: 0.6685 - loss: 0.0295 - precision: 0.2418 - recall: 0.2785 - val_accuracy: 0.9121 - val_auc: 0.7971 - val_loss: 0.0315 - val_precision: 0.4074 - val_recall: 0.4074
# Epoch 8/50
# 35/35 - 41s - 1s/step - accuracy: 0.8626 - auc: 0.7301 - loss: 0.0279 - precision: 0.1682 - recall: 0.2278 - val_accuracy: 0.9093 - val_auc: 0.6813 - val_loss: 0.0219 - val_precision: 0.1250 - val_recall: 0.0370
# Epoch 9/50
# 35/35 - 41s - 1s/step - accuracy: 0.8910 - auc: 0.6960 - loss: 0.0245 - precision: 0.2619 - recall: 0.2785 - val_accuracy: 0.8956 - val_auc: 0.7376 - val_loss: 0.0259 - val_precision: 0.1765 - val_recall: 0.1111
# Epoch 10/50
# 35/35 - 33s - 944ms/step - accuracy: 0.8929 - auc: 0.7456 - loss: 0.0236 - precision: 0.3173 - recall: 0.4177 - val_accuracy: 0.9231 - val_auc: 0.8370 - val_loss: 0.0175 - val_precision: 0.4000 - val_recall: 0.0741
# Epoch 11/50
# 35/35 - 41s - 1s/step - accuracy: 0.9011 - auc: 0.8052 - loss: 0.0185 - precision: 0.3165 - recall: 0.3165 - val_accuracy: 0.9368 - val_auc: 0.8989 - val_loss: 0.0159 - val_precision: 0.7000 - val_recall: 0.2593
# Epoch 12/50
# 35/35 - 41s - 1s/step - accuracy: 0.9112 - auc: 0.8188 - loss: 0.0195 - precision: 0.3977 - recall: 0.4430 - val_accuracy: 0.9231 - val_auc: 0.8887 - val_loss: 0.0181 - val_precision: 0.4444 - val_recall: 0.1481
# Epoch 13/50
# 35/35 - 41s - 1s/step - accuracy: 0.9222 - auc: 0.8119 - loss: 0.0188 - precision: 0.4583 - recall: 0.4177 - val_accuracy: 0.9286 - val_auc: 0.9237 - val_loss: 0.0171 - val_precision: 0.5714 - val_recall: 0.1481
# Epoch 14/50
# 35/35 - 41s - 1s/step - accuracy: 0.9139 - auc: 0.8221 - loss: 0.0192 - precision: 0.4176 - recall: 0.4810 - val_accuracy: 0.9341 - val_auc: 0.8954 - val_loss: 0.0135 - val_precision: 0.7143 - val_recall: 0.1852
# Epoch 15/50
# 35/35 - 41s - 1s/step - accuracy: 0.9148 - auc: 0.8699 - loss: 0.0167 - precision: 0.4125 - recall: 0.4177 - val_accuracy: 0.9286 - val_auc: 0.8782 - val_loss: 0.0158 - val_precision: 0.6667 - val_recall: 0.0741
# Epoch 16/50
# 35/35 - 40s - 1s/step - accuracy: 0.9167 - auc: 0.8820 - loss: 0.0160 - precision: 0.4211 - recall: 0.4051 - val_accuracy: 0.9396 - val_auc: 0.9142 - val_loss: 0.0141 - val_precision: 0.7778 - val_recall: 0.2593
# Epoch 17/50
# 35/35 - 41s - 1s/step - accuracy: 0.9212 - auc: 0.8676 - loss: 0.0159 - precision: 0.4568 - recall: 0.4684 - val_accuracy: 0.9451 - val_auc: 0.9067 - val_loss: 0.0162 - val_precision: 0.6667 - val_recall: 0.5185
# Epoch 18/50
# 35/35 - 40s - 1s/step - accuracy: 0.9203 - auc: 0.8593 - loss: 0.0155 - precision: 0.4487 - recall: 0.4430 - val_accuracy: 0.9423 - val_auc: 0.9422 - val_loss: 0.0153 - val_precision: 0.7500 - val_recall: 0.3333
# Epoch 19/50
# 35/35 - 42s - 1s/step - accuracy: 0.9286 - auc: 0.9060 - loss: 0.0142 - precision: 0.5062 - recall: 0.5190 - val_accuracy: 0.9368 - val_auc: 0.9063 - val_loss: 0.0176 - val_precision: 0.8333 - val_recall: 0.1852
# Epoch 20/50
# 35/35 - 41s - 1s/step - accuracy: 0.9240 - auc: 0.9073 - loss: 0.0133 - precision: 0.4756 - recall: 0.4937 - val_accuracy: 0.9368 - val_auc: 0.9105 - val_loss: 0.0163 - val_precision: 0.8333 - val_recall: 0.1852
# Epoch 21/50
# 35/35 - 32s - 924ms/step - accuracy: 0.9222 - auc: 0.8842 - loss: 0.0153 - precision: 0.4659 - recall: 0.5190 - val_accuracy: 0.9505 - val_auc: 0.9341 - val_loss: 0.0131 - val_precision: 0.7368 - val_recall: 0.5185
# Epoch 22/50
# 35/35 - 42s - 1s/step - accuracy: 0.9414 - auc: 0.9347 - loss: 0.0100 - precision: 0.6119 - recall: 0.5190 - val_accuracy: 0.9478 - val_auc: 0.9083 - val_loss: 0.0130 - val_precision: 0.7857 - val_recall: 0.4074
# Epoch 23/50
# 35/35 - 40s - 1s/step - accuracy: 0.9524 - auc: 0.9588 - loss: 0.0090 - precision: 0.6753 - recall: 0.6582 - val_accuracy: 0.9423 - val_auc: 0.9025 - val_loss: 0.0135 - val_precision: 0.8000 - val_recall: 0.2963
# Epoch 24/50
# 35/35 - 40s - 1s/step - accuracy: 0.9478 - auc: 0.9595 - loss: 0.0090 - precision: 0.6618 - recall: 0.5696 - val_accuracy: 0.9505 - val_auc: 0.9066 - val_loss: 0.0140 - val_precision: 0.7647 - val_recall: 0.4815
# Epoch 25/50
# 35/35 - 41s - 1s/step - accuracy: 0.9441 - auc: 0.9602 - loss: 0.0085 - precision: 0.6071 - recall: 0.6456 - val_accuracy: 0.9423 - val_auc: 0.9116 - val_loss: 0.0153 - val_precision: 0.6875 - val_recall: 0.4074
# Epoch 26/50
# 35/35 - 41s - 1s/step - accuracy: 0.9469 - auc: 0.9631 - loss: 0.0087 - precision: 0.6364 - recall: 0.6203 - val_accuracy: 0.9478 - val_auc: 0.9045 - val_loss: 0.0147 - val_precision: 0.7500 - val_recall: 0.4444
# Epoch 27/50
# 35/35 - 42s - 1s/step - accuracy: 0.9606 - auc: 0.9705 - loss: 0.0074 - precision: 0.7308 - recall: 0.7215 - val_accuracy: 0.9533 - val_auc: 0.8964 - val_loss: 0.0143 - val_precision: 0.8125 - val_recall: 0.4815
# Epoch 28/50
# 35/35 - 41s - 1s/step - accuracy: 0.9625 - auc: 0.9761 - loss: 0.0064 - precision: 0.7317 - recall: 0.7595 - val_accuracy: 0.9451 - val_auc: 0.8931 - val_loss: 0.0160 - val_precision: 0.7692 - val_recall: 0.3704
# Epoch 29/50
# 35/35 - 40s - 1s/step - accuracy: 0.9579 - auc: 0.9619 - loss: 0.0073 - precision: 0.7200 - recall: 0.6835 - val_accuracy: 0.9505 - val_auc: 0.9078 - val_loss: 0.0151 - val_precision: 0.7647 - val_recall: 0.4815
# Epoch 30/50
# 35/35 - 32s - 907ms/step - accuracy: 0.9634 - auc: 0.9735 - loss: 0.0067 - precision: 0.7746 - recall: 0.6962 - val_accuracy: 0.9533 - val_auc: 0.8626 - val_loss: 0.0159 - val_precision: 0.7500 - val_recall: 0.5556
# Epoch 31/50
# 35/35 - 40s - 1s/step - accuracy: 0.9689 - auc: 0.9854 - loss: 0.0059 - precision: 0.8082 - recall: 0.7468 - val_accuracy: 0.9533 - val_auc: 0.8926 - val_loss: 0.0158 - val_precision: 0.8125 - val_recall: 0.4815
# Epoch 32/50
# 35/35 - 41s - 1s/step - accuracy: 0.9689 - auc: 0.9716 - loss: 0.0068 - precision: 0.8000 - recall: 0.7595 - val_accuracy: 0.9505 - val_auc: 0.8993 - val_loss: 0.0157 - val_precision: 0.7647 - val_recall: 0.4815
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step
# All results saved to CSV.
